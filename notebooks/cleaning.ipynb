# %%
import pandas as pd
import os
import uuid
import requests
import requests_cache
from datetime import timedelta
from typing import Union

session = requests_cache.CachedSession('paper_cache', expire_after=timedelta(hours=24))

# %% [markdown]
# # Read in authors

# %%
filepath = os.path.join('data', 'author_list.xlsx')
authors = pd.read_excel(filepath)

# %%
authors.columns
# Out:
# Index(['Index', 'Last Name', 'First Name', 'Orcid', 'google_scholar', 'pubmed',
#        'institution_url'],
#       dtype='object')

# %% [markdown]
# ## Remove authors with a duplicate ORCID

# %%
deduped = authors[~authors.duplicated(subset='Orcid') | authors['Orcid'].isna() ]

# %% [markdown]
# ## Remove authors with a duplicate ORCID/no ORCID keeping ORCID

# %%
name = deduped['Last Name'].str.strip().str.lower() + deduped['First Name'].str.strip().str.lower().str.get(0)
deduped['name'] = name.copy()
deduped = deduped[~name.duplicated(keep='first')].sort_values('Last Name')
# Out:
# /var/folders/_7/bccbfn110b501smf76mty7xh0000gn/T/ipykernel_41279/4072643918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deduped['name'] = name.copy()

# %%
deduped
# Out:
#      Index    Last Name     First Name                                  Orcid  \
# 54      59      Abraham            Edo  https://orcid.org/0000-0003-0989-5456
# 249     60         Adam      Jean-Paul                                    NaN
# 162     31     Agarwala        Matthew  https://orcid.org/0000-0002-0042-2559
# 250     61  Agbemabiese       Lawrence                                    NaN
# 14      62        Agutu      Churchill  https://orcid.org/0000-0003-3511-9960
# ..     ...          ...            ...                                    ...
# 174    242     Yeganyan         Rudolf  https://orcid.org/0000-0001-9325-8147
# 72     104      Yussuff   Abdulmutalib  https://orcid.org/0000-0002-9565-305X
# 343    116         Zhou         Zhaoqi                                    NaN
# 263    150     d'Avezac         Mayeul                                    NaN
# 117      2      van Dam        Koen H.  https://orcid.org/0000-0002-4879-9259
#
#                                         google_scholar  pubmed  \
# 54                                                 NaN     NaN
# 249                                                NaN     NaN
# 162                                                NaN     NaN
# 250  https://scholar.google.co.uk/citations?hl=en&u...     NaN
# 14                                                 NaN     NaN
# ..                                                 ...     ...
# 174                                                NaN     NaN
# 72                                                 NaN     NaN
# 343                                                NaN     NaN
# 263                                                NaN     NaN
# 117                                                NaN     NaN
#
#                                        institution_url          name
# 54                                                 NaN      abrahame
# 249                                                NaN         adamj
# 162                                                NaN     agarwalam
# 250                                                NaN  agbemabiesel
# 14                                                 NaN        agutuc
# ..                                                 ...           ...
# 174                                                NaN     yeganyanr
# 72                                                 NaN      yussuffa
# 343  https://www.geog.ox.ac.uk/graduate/research/zz...         zhouz
# 263                                                NaN     d'avezacm
# 117                                                NaN      van damk
#
# [193 rows x 8 columns]

# %%
deduped['uuid'] = deduped['Last Name'].apply(lambda x: str(uuid.uuid4()))

# %% [markdown]
# # Read in papers and relations

# %%
filepath = os.path.join('data', 'papers.xlsx')
papers = pd.read_excel(filepath, sheet_name='Papers')
relations = pd.read_excel(filepath, sheet_name='Author Paper')

papers['paper_uuid'] = papers['DOI'].apply(lambda x: str(uuid.uuid4()))

relations = relations.merge(papers[['DOI', 'paper_uuid']], left_on='DOI', right_on='DOI', how='left')

# papers['DOI'] = 'https://doi.org/' + papers['DOI']

# %%
# Read in modified authors file
authors = pd.read_csv('data/authors_master.csv')
authors['name'] = authors['Last Name'].str.strip().str.lower() + authors['First Name'].str.strip().str.lower().str.get(0)
authors['uuid'] = authors['Last Name'].apply(lambda x: str(uuid.uuid4()))

# %%
authors_surname = authors.set_index('name')

relations['join_name'] = relations['Last_Name'].str.strip().str.lower() + relations['First_Name'].str.strip().str.lower().str.get(0)

joined = relations.join(other=authors_surname, on='join_name', validate="m:m")

# %%
papers
# Out:
#                                       DOI  \
# 0              10.1038/s41560-022-01152-0
# 1                      10.3390/en14185827
# 2              10.1038/s41598-023-28377-7
# 3            10.1016/j.respol.2022.104528
# 4               10.1016/j.esr.2022.100890
# 5              10.1038/s41560-022-01121-7
# 6               10.1016/j.esr.2021.100650
# 7                      10.3390/en14041209
# 8               10.1016/j.esr.2021.100799
# 9           10.1016/j.jclepro.2022.131014
# 10             10.1016/j.rser.2021.111935
# 11                     10.3390/su14010453
# 12              10.1016/j.esr.2022.100964
# 13          10.1016/j.envsoft.2021.105091
# 14              10.1016/j.esr.2022.100841
# 15          10.1016/j.tranpol.2022.12.007
# 16             10.1038/s41893-021-00721-7
# 17              10.1016/j.dib.2022.108691
# 18              10.1016/j.esd.2022.07.006
# 19             10.1007/s13280-022-01757-5
# 20              10.1016/j.esr.2021.100759
# 21         10.1016/j.progress.2022.100657
# 22              10.1016/j.dib.2021.107734
# 23              10.1016/j.dib.2022.108262
# 24              10.1016/j.esr.2021.100714
# 25            10.1007/978-3-031-20179-0_3
# 26              10.1016/j.jag.2022.102748
# 27              10.1016/j.esr.2021.100722
# 28             10.1016/j.erss.2021.102379
# 29  10.1146/annurev-environ-112420-020640
# 30              10.1016/j.dib.2022.108836
#
#                                              Abstract  \
# 0   Aligning development and climate goals means A...
# 1   Almost all countries have committed to develop...
# 2   As the world transitions to net zero, energy s...
# 3   Business model innovation (BMI) is often compl...
# 4   Deploying low-carbon electricity systems in de...
# 5   Energy development in Indigenous lands has bee...
# 6   Energy modelling is critical for addressing ch...
# 7   Ethiopia is a low-income country, with low ele...
# 8   Financial institutions around the world have a...
# 9   Formally adopting climate change mitigation po...
# 10  In order to provide “affordable, reliable, sus...
# 11  In this paper we investigate the economic resp...
# 12  Integrated assessment models (IAMs) are a corn...
# 13  Integrated Assessment Models (IAMs) are import...
# 14  Renewable energy development can enable climat...
# 15  Road transport accounts for around 12% of glob...
# 16  Sustainably transitioning to electric vehicles...
# 17  The 2019 Energy Act requires each of Kenya’s 4...
# 18  The 2030 Agenda for Sustainable Development ca...
# 19  The COVID-19 pandemic and related social and e...
# 20  The COVID-19 pandemic has affected the economy...
# 21  The COVID-19 pandemic highlighted the need for...
# 22  This article describes a dataset of perceived ...
# 23  This article presents a geolocated dataset of ...
# 24  This paper presents the first application of t...
# 25  This paper proposes an agent-based simulation ...
# 26  To implement effective rural electricity acces...
# 27  Transport is an integral component of the ener...
# 28  Understanding consumer needs and values is cru...
# 29  When deep recessions hit, some governments spe...
# 30  Viet Nam is at a critical juncture in planning...
#
#                               paper_uuid
# 0   bdcd53b3-034c-479d-8115-aaaf1d520f2c
# 1   9f8598d1-7fa9-4056-80e3-42eb7608eeda
# 2   4f168d4a-78fd-4c92-8597-6da222b17642
# 3   ba2a928d-69c2-48ef-a077-e30ebea64491
# 4   ddf2cfd5-cf3b-4d8e-92df-9c905cce1b49
# 5   e19e1b94-105f-489c-9380-98fc395c4ffa
# 6   6425b47b-65de-4bb2-9491-21a403b58efd
# 7   f012c5b9-78b3-4713-ac70-8c4454788022
# 8   2507dd90-e6b6-4c8e-a8b4-99d49629739c
# 9   23b848e4-745b-4aa7-baff-72866d673c02
# 10  0b7e5db6-d376-43e6-adde-83a36895cee1
# 11  b045aef4-b0aa-45a7-b9d4-1e9a399af475
# 12  ce6ed5ea-221e-44cd-8173-f04da6e140f4
# 13  9d5ea1e2-c070-4390-8175-6b6197fb090f
# 14  7035e71f-2f85-49b1-b97c-ea7d9b438d07
# 15  94700b64-e1d8-4716-9bf6-bde5d3a0f26f
# 16  93d05c7e-0376-432a-b209-9a31ab01b7ce
# 17  e27fbbbc-c2ff-476a-ab40-47b3a223a1b0
# 18  70aa944a-67f8-4c9c-8fe5-8248039a31b7
# 19  17746a4b-c6d2-4920-8a35-cc5e393270ac
# 20  7d682e80-ae14-49e8-bc98-fad0e6b074e4
# 21  fc24b776-fcf0-4369-a069-3d82e0f1d69f
# 22  786c66c6-10fe-4b0f-bd15-10d5dd8e6735
# 23  01e7b79b-9618-438c-9de1-a9bbf0d244d1
# 24  9e77e6ef-8e6c-452e-b778-3d6779cfc475
# 25  6d82605a-4b5d-4c5a-9360-6dd8ee3a6051
# 26  f0feda8f-afc5-41d6-a7eb-f9faeedcf08b
# 27  0cd1544c-39ac-4251-8796-5d50df4b1ea9
# 28  247e3530-c8c8-41d7-87bc-5e761605e047
# 29  b3f7a935-e19d-48e4-828f-434447dfd7b0
# 30  48fdaa55-7bbd-4d75-ba1f-231a30075f7b

# %%
# joined = joined.set_index('DOI').join(other=papers.set_index('DOI'), on='DOI', validate="m:1")
joined
# Out:
#            First_Name   Last_Name                          DOI  \
# 0                 Liu        Yang  10.1007/978-3-031-20179-0_3
# 1             Koen H.     van Dam  10.1007/978-3-031-20179-0_3
# 2             Michael      Vardon   10.1007/s13280-022-01757-5
# 3                Paul       Lucas   10.1007/s13280-022-01757-5
# 4               Steve        Bass   10.1007/s13280-022-01757-5
# ..                ...         ...                          ...
# 199              John    Harrison    10.1016/j.dib.2022.108836
# 200              Mark     Howells    10.1016/j.dib.2022.108836
# 201            Rudolf    Yeganyan    10.1016/j.dib.2022.108836
# 202  Shaikh M. S. U.     Eskander           10.3390/su14010453
# 203              Sam   Fankhauser           10.3390/su14010453
#
#                                paper_uuid    join_name       First Name  \
# 0    6d82605a-4b5d-4c5a-9360-6dd8ee3a6051        yangl              Liu
# 1    6d82605a-4b5d-4c5a-9360-6dd8ee3a6051     van damk             Koen
# 2    17746a4b-c6d2-4920-8a35-cc5e393270ac      vardonm          Michael
# 3    17746a4b-c6d2-4920-8a35-cc5e393270ac       lucasp             Paul
# 4    17746a4b-c6d2-4920-8a35-cc5e393270ac        basss            Steve
# ..                                    ...          ...              ...
# 199  48fdaa55-7bbd-4d75-ba1f-231a30075f7b    harrisonj             John
# 200  48fdaa55-7bbd-4d75-ba1f-231a30075f7b     howellsm             Mark
# 201  48fdaa55-7bbd-4d75-ba1f-231a30075f7b    yeganyanr           Rudolf
# 202  b045aef4-b0aa-45a7-b9d4-1e9a399af475    eskanders  Shaikh M. S. U.
# 203  b045aef4-b0aa-45a7-b9d4-1e9a399af475  fankhausers           Samuel
#
#       Last Name                                  Orcid  \
# 0          Yang  https://orcid.org/0000-0002-3363-8620
# 1       van Dam  https://orcid.org/0000-0002-4879-9259
# 2        Vardon  https://orcid.org/0000-0002-5708-6824
# 3         Lucas  https://orcid.org/0000-0003-0292-7830
# 4          Bass                                    NaN
# ..          ...                                    ...
# 199    Harrison  https://orcid.org/0000-0002-6434-5142
# 200     Howells  https://orcid.org/0000-0001-6419-4957
# 201    Yeganyan  https://orcid.org/0000-0001-9325-8147
# 202    Eskander                                    NaN
# 203  Fankhauser  https://orcid.org/0000-0003-2100-7888
#
#                                         google_scholar  pubmed  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4    https://scholar.google.co.uk/citations?hl=en&u...     NaN
# ..                                                 ...     ...
# 199                                                NaN     NaN
# 200                                                NaN     NaN
# 201                                                NaN     NaN
# 202                                                NaN     NaN
# 203                                                NaN     NaN
#
#     institution_url gender                                  uuid
# 0               NaN   male  65fd4a16-a6ed-4167-91ad-0e600638ad9c
# 1               NaN   male  4c112571-59b8-4afc-b6cc-63905cc2fbe6
# 2               NaN   male  5749ceef-715d-48e8-a5c3-2cdbeca26a15
# 3               NaN   male  faa76dd9-c08a-426c-af48-582f0676d59c
# 4               NaN   male  52af1594-19d2-4e9b-bb3d-2c4f19283726
# ..              ...    ...                                   ...
# 199             NaN   male  497e2199-283f-4b19-b709-481acbf5da8d
# 200             NaN   male  de7075f2-8cf5-459f-a754-34684a808d0d
# 201             NaN   male  33a47266-b0b8-4ca7-9fc8-7f1f3908e6f3
# 202             NaN   male  2536def5-f55f-41bc-9934-5859cce812e3
# 203             NaN   male  6da3f364-a033-421e-b06d-d967ec762966
#
# [204 rows x 13 columns]

# %%
authors_surname[authors_surname.index.str.contains('gebr')]
# Out:
#                        First Name      Last Name  \
# name
# gebresilassiee  Eshetu Gebrekidan  Gebresilassie
# gebreslassiem            Mulualem   Gebreslassie
#
#                                                 Orcid google_scholar  pubmed  \
# name
# gebresilassiee  https://orcid.org/0000-0001-8834-2766            NaN     NaN
# gebreslassiem   https://orcid.org/0000-0002-5509-5866            NaN     NaN
#
#                institution_url gender                                  uuid
# name
# gebresilassiee             NaN   male  470add76-d703-406e-ba15-d2af3ca99522
# gebreslassiem              NaN   male  0f61f058-a41a-44ec-bfb5-c39aac18a165

# %%
relations[relations['join_name'].str.contains('gebr')]
# Out:
#            First_Name      Last_Name                         DOI  \
# 46  Eshetu Gebrekidan  Gebresilassie  10.1038/s41560-022-01152-0
# 47           Mulualem   Gebreslassie  10.1038/s41560-022-01152-0
#
#                               paper_uuid       join_name
# 46  bdcd53b3-034c-479d-8115-aaaf1d520f2c  gebresilassiee
# 47  bdcd53b3-034c-479d-8115-aaaf1d520f2c   gebreslassiem

# %%
joined.columns
# Out:
# Index(['First_Name', 'Last_Name', 'DOI', 'paper_uuid', 'join_name',
#        'First Name', 'Last Name', 'Orcid', 'google_scholar', 'pubmed',
#        'institution_url', 'gender', 'uuid'],
#       dtype='object')

# %% [markdown]
# ## Validate joined results

# %%
joined.columns
# Out:
# Index(['First_Name', 'Last_Name', 'DOI', 'paper_uuid', 'join_name',
#        'First Name', 'Last Name', 'Orcid', 'google_scholar', 'pubmed',
#        'institution_url', 'gender', 'uuid'],
#       dtype='object')

# %%
joined[joined['First_Name'].str.strip().str.get(0) != joined['First Name'].str.strip().str.get(0)]
# Out:
# Empty DataFrame
# Columns: [First_Name, Last_Name, DOI, paper_uuid, join_name, First Name, Last Name, Orcid, google_scholar, pubmed, institution_url, gender, uuid]
# Index: []

# %%
joined.to_excel('data/joined.xlsx')

# %%
joined.sample()
# Out:
#     First_Name Last_Name                        DOI  \
# 124         F.   Gardumi  10.1016/j.esd.2022.07.006
#
#                                paper_uuid join_name First Name Last Name  \
# 124  70aa944a-67f8-4c9c-8fe5-8248039a31b7  gardumif  Francesco   Gardumi
#
#                                      Orcid google_scholar  pubmed  \
# 124  https://orcid.org/0000-0001-8371-9325            NaN     NaN
#
#     institution_url gender                                  uuid
# 124             NaN   male  90cd58b0-23c4-41b7-bba3-470cbcb889b3

# %%
for column in ['First Name', 'Last Name', 'Orcid']:
    print(column)
    joined[column] = joined[column].str.strip()
authors = joined[['uuid', 'First Name', 'Last Name', 'Orcid', 'google_scholar', 'pubmed', 'institution_url', 'gender']]
authors = authors.drop_duplicates(keep='first')
# Out:
# First Name
# Last Name
# Orcid

# %%
authors.to_csv('data/authors.csv', index=False)

# %%
relations = joined[['uuid','paper_uuid']]
relations.to_csv('data/relations.csv', index=False)

papers.to_csv('data/papers.csv', index=False)

# %% [markdown]
# # Add genders

# %%
# Out:
#                                      uuid       First Name Last Name  \
# 0    e851cf3d-1c2f-4a4d-a1a2-61e4275ea2bc              Liu      Yang
# 1    7765a41c-57f9-497b-9a31-7bd2537544f6             Koen   van Dam
# 2    fc7e83e7-4f64-4a73-be71-38edc6281f4b          Michael    Vardon
# 3    743b0d6b-f946-4ce9-903b-6885bd2c0e0f             Paul     Lucas
# 4    b640402a-46d6-48e7-9f99-d120404d717a            Steve      Bass
# ..                                    ...              ...       ...
# 194  7d75d0fb-6303-444c-80a0-c023d0e56170            Layla   Khanfar
# 198  376b13a9-836d-44a7-856d-f67744da1ca4            Naomi       Tan
# 199  9b9e1d67-3fa9-43b2-b65e-3fbaed6e0e3c             John  Harrison
# 201  dd043f0d-9f53-480d-9edf-385c5899b7fc           Rudolf  Yeganyan
# 202  692635eb-b0db-4d85-84c9-91ac3868fcba  Shaikh M. S. U.  Eskander
#
#                                      Orcid  \
# 0    https://orcid.org/0000-0002-3363-8620
# 1    https://orcid.org/0000-0002-4879-9259
# 2    https://orcid.org/0000-0002-5708-6824
# 3    https://orcid.org/0000-0003-0292-7830
# 4                                      NaN
# ..                                     ...
# 194                                    NaN
# 198  https://orcid.org/0000-0001-7957-8451
# 199  https://orcid.org/0000-0002-6434-5142
# 201  https://orcid.org/0000-0001-9325-8147
# 202                                    NaN
#
#                                         google_scholar  pubmed  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4    https://scholar.google.co.uk/citations?hl=en&u...     NaN
# ..                                                 ...     ...
# 194                                                NaN     NaN
# 198                                                NaN     NaN
# 199                                                NaN     NaN
# 201                                                NaN     NaN
# 202                                                NaN     NaN
#
#     institution_url  gender
# 0               NaN    male
# 1               NaN    male
# 2               NaN    male
# 3               NaN    male
# 4               NaN    male
# ..              ...     ...
# 194             NaN  female
# 198             NaN  female
# 199             NaN    male
# 201             NaN    male
# 202             NaN    male
#
# [154 rows x 8 columns]

# %%
genders = pd.read_csv('data/authors_gendered.csv', usecols=['First Name', 'Last Name', 'Orcid', 'gender'])
genders['name'] = genders['Last Name'].str.strip().str.lower() + genders['First Name'].str.strip().str.lower().str.get(0)
authors = authors.join(genders[~genders['Orcid'].isna()].set_index('Orcid')['gender'], on='Orcid', how='right')
authors['name'] = authors['Last Name'].str.strip().str.lower() + authors['First Name'].str.strip().str.lower().str.get(0)
authors = authors.join(genders.set_index('name')['gender'], on='name', how='left', rsuffix='name_')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 genders = pd.read_csv('data/authors_gendered.csv', usecols=['First Name', 'Last Name', 'Orcid', 'gender'])
#       2 genders['name'] = genders['Last Name'].str.strip().str.lower() + genders['First Name'].str.strip().str.lower().str.get(0)
# ----> 3 authors = authors.join(genders[~genders['Orcid'].isna()].set_index('Orcid')['gender'], on='Orcid', how='right')
#       4 authors['name'] = authors['Last Name'].str.strip().str.lower() + authors['First Name'].str.strip().str.lower().str.get(0)
#       5 authors = authors.join(genders.set_index('name')['gender'], on='name', how='left', rsuffix='name_')
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
#    9986         validate=validate,
#    9987     )
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/frame.py:10018, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10008     if how == "cross":
#   10009         return merge(
#   10010             self,
#   10011             other,
#    (...)
#   10016             validate=validate,
#   10017         )
# > 10018     return merge(
#   10019         self,
#   10020         other,
#   10021         left_on=on,
#   10022         how=how,
#   10023         left_index=on is None,
#   10024         right_index=True,
#   10025         suffixes=(lsuffix, rsuffix),
#   10026         sort=sort,
#   10027         validate=validate,
#   10028     )
#   10029 else:
#   10030     if on is not None:
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/merge.py:775, in _MergeOperation.get_result(self, copy)
#     771     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     773 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 775 result = self._reindex_and_concat(
#     776     join_index, left_indexer, right_indexer, copy=copy
#     777 )
#     778 result = result.__finalize__(self, method=self._merge_type)
#     780 if self.indicator:
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/merge.py:729, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     726 left = self.left[:]
#     727 right = self.right[:]
# --> 729 llabels, rlabels = _items_overlap_with_suffix(
#     730     self.left._info_axis, self.right._info_axis, self.suffixes
#     731 )
#     733 if left_indexer is not None:
#     734     # Pinning the index here (and in the right code just below) is not
#     735     #  necessary, but makes the `.take` more performant if we have e.g.
#     736     #  a MultiIndex for left.index.
#     737     lmgr = left._mgr.reindex_indexer(
#     738         join_index,
#     739         left_indexer,
#    (...)
#     744         use_na_proxy=True,
#     745     )
#
# File ~/miniconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/merge.py:2458, in _items_overlap_with_suffix(left, right, suffixes)
#    2455 lsuffix, rsuffix = suffixes
#    2457 if not lsuffix and not rsuffix:
# -> 2458     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2460 def renamer(x, suffix):
#    2461     """
#    2462     Rename the left and right indices.
#    2463
#    (...)
#    2474     x : renamed column name
#    2475     """
#
# ValueError: columns overlap but no suffix specified: Index(['gender'], dtype='object')

# %%
authors
# Out:
#                                      uuid       First Name Last Name  \
# 0    e851cf3d-1c2f-4a4d-a1a2-61e4275ea2bc              Liu      Yang
# 1    7765a41c-57f9-497b-9a31-7bd2537544f6             Koen   van Dam
# 2    fc7e83e7-4f64-4a73-be71-38edc6281f4b          Michael    Vardon
# 3    743b0d6b-f946-4ce9-903b-6885bd2c0e0f             Paul     Lucas
# 4    b640402a-46d6-48e7-9f99-d120404d717a            Steve      Bass
# ..                                    ...              ...       ...
# 194  7d75d0fb-6303-444c-80a0-c023d0e56170            Layla   Khanfar
# 198  376b13a9-836d-44a7-856d-f67744da1ca4            Naomi       Tan
# 199  9b9e1d67-3fa9-43b2-b65e-3fbaed6e0e3c             John  Harrison
# 201  dd043f0d-9f53-480d-9edf-385c5899b7fc           Rudolf  Yeganyan
# 202  692635eb-b0db-4d85-84c9-91ac3868fcba  Shaikh M. S. U.  Eskander
#
#                                      Orcid  \
# 0    https://orcid.org/0000-0002-3363-8620
# 1    https://orcid.org/0000-0002-4879-9259
# 2    https://orcid.org/0000-0002-5708-6824
# 3    https://orcid.org/0000-0003-0292-7830
# 4                                      NaN
# ..                                     ...
# 194                                    NaN
# 198  https://orcid.org/0000-0001-7957-8451
# 199  https://orcid.org/0000-0002-6434-5142
# 201  https://orcid.org/0000-0001-9325-8147
# 202                                    NaN
#
#                                         google_scholar  pubmed  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4    https://scholar.google.co.uk/citations?hl=en&u...     NaN
# ..                                                 ...     ...
# 194                                                NaN     NaN
# 198                                                NaN     NaN
# 199                                                NaN     NaN
# 201                                                NaN     NaN
# 202                                                NaN     NaN
#
#     institution_url  gender
# 0               NaN    male
# 1               NaN    male
# 2               NaN    male
# 3               NaN    male
# 4               NaN    male
# ..              ...     ...
# 194             NaN  female
# 198             NaN  female
# 199             NaN    male
# 201             NaN    male
# 202             NaN    male
#
# [154 rows x 8 columns]

# %%
g.serialize('authors.ttl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 g.serialize('authors.ttl')
#
# NameError: name 'g' is not defined

# %% [markdown]
# ## Returns the abstracts of the papers of a given author
#
# ```sparql
# PREFIX schema: <https://schema.org/>
#
# SELECT ?abstract
# WHERE {
#     ?s a schema:ScholarlyArticle .
#     ?s schema:abstract ?abstract .
#     ?s schema:author ?author .
#     ?author schema:name "Ioannis Pappis" .
# } LIMIT 100
# ```
#
# ## Returns the number of publications by author
#
# ```sparql
# PREFIX schema: <https://schema.org/>
#
# SELECT ?name (COUNT(?s) as ?count)
# WHERE {
#     ?s a schema:ScholarlyArticle .
#     ?s schema:author ?author .
#     ?author schema:name ?name .
# }
# GROUP BY ?name
# ORDER BY DESC(?count)
# ```
#
# ## Number of authors per open licensed publication
#
# ```sparql
# PREFIX schema: <https://schema.org/>
#
# SELECT ?title (COUNT(?author) as ?count)
# WHERE {
#     ?s a schema:ScholarlyArticle .
#     ?s schema:title ?title .
#     ?s schema:license ?license
#     FILTER CONTAINS(?license, "licenses/by/4.0") .
#     ?s schema:author ?author .
# }
# GROUP BY ?title
# ```

# %%
# Out:
#     uuid       First Name Last Name                                  Orcid  \
# 0    NaN              Liu      Yang  https://orcid.org/0000-0002-3363-8620
# 1    NaN             Koen   van Dam  https://orcid.org/0000-0002-4879-9259
# 2    NaN          Michael    Vardon  https://orcid.org/0000-0002-5708-6824
# 3    NaN             Paul     Lucas  https://orcid.org/0000-0003-0292-7830
# 4    NaN            Steve      Bass                                    NaN
# ..   ...              ...       ...                                    ...
# 194  NaN            Layla   Khanfar                                    NaN
# 198  NaN            Naomi       Tan  https://orcid.org/0000-0001-7957-8451
# 199  NaN             John  Harrison  https://orcid.org/0000-0002-6434-5142
# 201  NaN           Rudolf  Yeganyan  https://orcid.org/0000-0001-9325-8147
# 202  NaN  Shaikh M. S. U.  Eskander                                    NaN
#
#                                         google_scholar  pubmed  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4    https://scholar.google.co.uk/citations?hl=en&u...     NaN
# ..                                                 ...     ...
# 194                                                NaN     NaN
# 198                                                NaN     NaN
# 199                                                NaN     NaN
# 201                                                NaN     NaN
# 202                                                NaN     NaN
#
#     institution_url  gender
# 0               NaN    male
# 1               NaN    male
# 2               NaN    male
# 3               NaN    male
# 4               NaN    male
# ..              ...     ...
# 194             NaN  female
# 198             NaN  female
# 199             NaN    male
# 201             NaN    male
# 202             NaN    male
#
# [154 rows x 8 columns]
