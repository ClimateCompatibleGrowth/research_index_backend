# %%
import pandas as pd
import os
import uuid
import requests
import requests_cache
from datetime import timedelta
from typing import Union

session = requests_cache.CachedSession('paper_cache', expire_after=timedelta(hours=24))
# Out:
# /var/folders/_7/bccbfn110b501smf76mty7xh0000gn/T/ipykernel_46253/4138125344.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Text mining a CrossRef DOI

# %%
# FCDO - http://dx.doi.org/10.13039/501100020171

# def get_doi_by_orcid(orcid):
orcid = "0000-0002-3363-8620"
message = session.get(f"https://api.crossref.org/works?filter=orcid:{orcid}&select=DOI,title,prefix,published")
items = message.json()['message']['items']
for item in items:
   work = get_doi(item['DOI'])
   authors = work.json()['message']['author']

# %%
work = get_doi(items[0]['DOI'])
work.json()['message']['author']
# Out:
# [{'ORCID': 'http://orcid.org/0000-0002-3363-8620',
#   'authenticated-orcid': False,
#   'given': 'Liu',
#   'family': 'Yang',
#   'sequence': 'first',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0002-4879-9259',
#   'authenticated-orcid': False,
#   'given': 'Koen',
#   'family': 'van Dam',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'Lufeng',
#   'family': 'Zhang',
#   'sequence': 'additional',
#   'affiliation': []}]

# %%
work = get_doi("10.21203/rs.3.rs-478581/v1")

# %%
def get_doi(doi: str) -> Union[requests_cache.CachedSession, None]:

    url = f"https://api.crossref.org/works/{doi}/agency"

    agency = session.get(url)
    if agency.json()['message']['agency']['id'] == 'crossref':
        return session.get(f"https://api.crossref.org/works/{doi}")
    else:
        print(agency.status_code)
        return None

# %%
def get_titles(df):
    doi = df['DOI']
    work = get_doi(doi)
    if work:
        message = work.json()['message']
        title = message['title'][0]
        license = [x['URL'] for x in message['license'] if x['content-version'] == 'vor']
        if license:
            license = license[0]
        return (title, license)
    else:
        return (None, None)

papers = pd.read_csv('data/papers.csv')

papers[['title', 'license']] = papers.apply(get_titles, axis=1, result_type='expand')

papers.to_csv('data/papers.csv', index=False)

# %%
doi = "10.1016/j.jag.2022.102748"
work = requests.get(f"https://api.crossref.org/works/{doi}")

message = work.json()['message']

# %%
vor_license = [x['URL'] for x in message['license'] if x['content-version'] == 'vor'][0]
vor_license

# %%
authors = pd.read_csv('data/authors.csv')

# %%
test = authors[authors['uuid'] == "bed6dcc4-101a-44df-893e-f6148c96afb9"]['Orcid'].values

# %%
pd.isna(test)
# Out:
# array([False])

# %%
test
# Out:
# array(['https://orcid.org/0000-0002-3363-8620'], dtype=object)

# %%
pd.isna(test[0])
# Out:
# False

# %%
from create_graph import main
from rdflib import SDO, Namespace

g = main()

# %%
res = g.query(
    """
PREFIX schema: <https://schema.org/>
PREFIX org: <http://www.w3.org/ns/org#>

SELECT ?orcid
WHERE {
    # ?orcid org:memberOf ?organisation .
    # ?orcid a org:Organization .
    FILTER NOT EXISTS {
    # ?orcid schema:name ?name .
		}
    }
    """
)

# %%
for row in res:
    print(f"{row.orcid}")
# Out:
# http://climatecompatiblegrowth.com/id/oxford
# http://climatecompatiblegrowth.com/id/kth
# http://climatecompatiblegrowth.com/id/cambridge
# http://climatecompatiblegrowth.com/id/loughborough
# http://climatecompatiblegrowth.com/id/imperial
# http://climatecompatiblegrowth.com/id/cge
# http://climatecompatiblegrowth.com/id/ou
# http://climatecompatiblegrowth.com/id/ucl
# http://climatecompatiblegrowth.com/id/cp

# %% [markdown]
# # Try the crossref commons python package

# %%
import crossref_commons.retrieval

def get_doi_datacite(doi: str) -> Union[requests_cache.CachedSession, None]:

    url = f"https://api.datacite.org/dois/{doi}"

    agency = session.get(url)
    return agency.json()['data']['attributes']

def get_data(doi: str):
    try:
        result = crossref_commons.retrieval.get_publication_as_json(doi)
    except ValueError as ex:
        # try Zenodo API
        result = get_doi_datacite(doi)
    return result

doi = "10.5281/zenodo.10411123"
zenodo_dataset = get_data(doi)

doi = "10.3390/en14041209"
publication = get_data(doi)

# %%
zenodo_dataset
# Out:
# {'doi': '10.5281/zenodo.10411123',
#  'prefix': '10.5281',
#  'suffix': 'zenodo.10411123',
#  'identifiers': [{'identifier': 'oai:zenodo.org:10411123',
#    'identifierType': 'oai'}],
#  'alternateIdentifiers': [{'alternateIdentifierType': 'oai',
#    'alternateIdentifier': 'oai:zenodo.org:10411123'}],
#  'creators': [{'name': 'Tan, Naomi',
#    'nameType': 'Personal',
#    'givenName': 'Naomi',
#    'familyName': 'Tan',
#    'affiliation': ['Loughborough University', 'Imperial College London'],
#    'nameIdentifiers': [{'nameIdentifier': '0000-0001-7957-8451',
#      'nameIdentifierScheme': 'ORCID'}]},
#   {'name': 'Ambunda, Robert',
#    'nameType': 'Personal',
#    'givenName': 'Robert',
#    'familyName': 'Ambunda',
#    'affiliation': ['SLOCAT Partnership'],
#    'nameIdentifiers': []},
#   {'name': 'Medimorec, Nikola',
#    'nameType': 'Personal',
#    'givenName': 'Nikola',
#    'familyName': 'Medimorec',
#    'affiliation': ['SLOCAT Partnership'],
#    'nameIdentifiers': [{'nameIdentifier': '0000-0003-2935-7495',
#      'nameIdentifierScheme': 'ORCID'}]},
#   {'name': 'Cortez, Angel',
#    'nameType': 'Personal',
#    'givenName': 'Angel',
#    'familyName': 'Cortez',
#    'affiliation': ['SLOCAT Partnership'],
#    'nameIdentifiers': []},
#   {'name': 'Krapp, Agustina',
#    'nameType': 'Personal',
#    'givenName': 'Agustina',
#    'familyName': 'Krapp',
#    'affiliation': ['SLOCAT Partnership'],
#    'nameIdentifiers': []},
#   {'name': 'Maxwell, Erin',
#    'nameType': 'Personal',
#    'givenName': 'Erin',
#    'familyName': 'Maxwell',
#    'affiliation': ['Loughborough University'],
#    'nameIdentifiers': [{'nameIdentifier': '0009-0004-4936-4080',
#      'nameIdentifierScheme': 'ORCID'}]}],
#  'titles': [{'title': 'Transport Starter Data Kit: Historical socio-transport data for Nigeria'}],
#  'publisher': 'Zenodo',
#  'container': {},
#  'publicationYear': 2023,
#  'subjects': [{'subject': 'Transport'},
#   {'subject': 'Data'},
#   {'subject': 'Nigeria'}],
#  'contributors': [],
#  'dates': [{'date': '2023-12-20', 'dateType': 'Issued'}],
#  'language': 'en',
#  'types': {'ris': 'DATA',
#   'bibtex': 'misc',
#   'citeproc': 'dataset',
#   'schemaOrg': 'Dataset',
#   'resourceType': '',
#   'resourceTypeGeneral': 'Dataset'},
#  'relatedIdentifiers': [{'relationType': 'IsVersionOf',
#    'relatedIdentifier': '10.5281/zenodo.6539979',
#    'relatedIdentifierType': 'DOI'}],
#  'relatedItems': [],
#  'sizes': [],
#  'formats': [],
#  'version': '3.0',
#  'rightsList': [{'rights': 'Creative Commons Attribution 4.0 International',
#    'rightsUri': 'https://creativecommons.org/licenses/by/4.0/legalcode',
#    'schemeUri': 'https://spdx.org/licenses/',
#    'rightsIdentifier': 'cc-by-4.0',
#    'rightsIdentifierScheme': 'SPDX'}],
#  'descriptions': [{'description': "This Transport Starter Data Kit contains historical annual data (1990–2021) on passenger and freight activity, segregated by mode and fuel. Additionally, historical data on energy intensities, load factors, vehicle stock, population (total, urban, rural, growth), and GDP (total, agriculture, construction, mining, manufacturing, service, energy, growth) are included in the kit, within the 'Data' tab. The historical data can be used as a foundation for transport-energy modelling and/or to identify areas of improvement. This data was verified through consultation with relevant stakeholders before publishing. The definition used for each vehicle mode is found in the 'Definitions' tab, and the description of each data observation status is found in the 'Notes' tab. All data sources are linked where possible.",
#    'descriptionType': 'Abstract'}],
#  'geoLocations': [],
#  'fundingReferences': [],
#  'xml': '...',
#  'url': 'https://zenodo.org/doi/10.5281/zenodo.10411123',
#  'contentUrl': None,
#  'metadataVersion': 0,
#  'schemaVersion': 'http://datacite.org/schema/kernel-4',
#  'source': 'api',
#  'isActive': True,
#  'state': 'findable',
#  'reason': None,
#  'viewCount': 0,
#  'viewsOverTime': [],
#  'downloadCount': 0,
#  'downloadsOverTime': [],
#  'referenceCount': 0,
#  'citationCount': 0,
#  'citationsOverTime': [],
#  'partCount': 0,
#  'partOfCount': 0,
#  'versionCount': 0,
#  'versionOfCount': 1,
#  'created': '2023-12-20T15:26:10.000Z',
#  'registered': '2023-12-20T15:26:10.000Z',
#  'published': '2023',
#  'updated': '2023-12-20T15:26:11.000Z'}

# %%
result['data'].keys()
# Out:
# dict_keys(['id', 'type', 'attributes', 'relationships'])

# %%
result['data']['attributes']['types']
# Out:
# {'ris': 'DATA',
#  'bibtex': 'misc',
#  'citeproc': 'dataset',
#  'schemaOrg': 'Dataset',
#  'resourceType': '',
#  'resourceTypeGeneral': 'Dataset'}

# %%
result['author']
# Out:
# [{'ORCID': 'http://orcid.org/0000-0001-7537-5470',
#   'authenticated-orcid': False,
#   'given': 'Ioannis',
#   'family': 'Pappis',
#   'sequence': 'first',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0002-1565-2752',
#   'authenticated-orcid': False,
#   'given': 'Andreas',
#   'family': 'Sahlberg',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'Tewodros',
#   'family': 'Walle',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0002-6179-927X',
#   'authenticated-orcid': False,
#   'given': 'Oliver',
#   'family': 'Broad',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0001-8801-9686',
#   'authenticated-orcid': False,
#   'given': 'Elusiyan',
#   'family': 'Eludoyin',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'Mark',
#   'family': 'Howells',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0001-9367-1791',
#   'authenticated-orcid': False,
#   'given': 'Will',
#   'family': 'Usher',
#   'sequence': 'additional',
#   'affiliation': []}]

# %%
print(result.keys())
# Out:
# dict_keys(['indexed', 'reference-count', 'publisher', 'issue', 'license', 'content-domain', 'short-container-title', 'abstract', 'DOI', 'type', 'created', 'page', 'source', 'is-referenced-by-count', 'title', 'prefix', 'volume', 'author', 'member', 'published-online', 'reference', 'container-title', 'original-title', 'language', 'link', 'deposited', 'score', 'resource', 'subtitle', 'short-title', 'issued', 'references-count', 'journal-issue', 'alternative-id', 'URL', 'relation', 'ISSN', 'issn-type', 'subject', 'published'])

# %%
print(f'{result["title"][0]} {result["publisher"]} {result["volume"]}')
# Out:
# Influence of Electrification Pathways in the Electricity Sector of Ethiopia—Policy Implications Linking Spatial Electrification Analysis and Medium to Long-Term Energy Planning MDPI AG 14

# %%
result["title"][0]
# Out:
# 'Influence of Electrification Pathways in the Electricity Sector of Ethiopia—Policy Implications Linking Spatial Electrification Analysis and Medium to Long-Term Energy Planning'

# %%
result
# Out:
# {'indexed': {'date-parts': [[2024, 2, 16]],
#   'date-time': '2024-02-16T23:28:22Z',
#   'timestamp': 1708126102284},
#  'reference-count': 104,
#  'publisher': 'MDPI AG',
#  'issue': '4',
#  'license': [{'start': {'date-parts': [[2021, 2, 23]],
#     'date-time': '2021-02-23T00:00:00Z',
#     'timestamp': 1614038400000},
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'URL': 'https://creativecommons.org/licenses/by/4.0/'}],
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['Energies'],
#  'abstract': '<jats:p>Ethiopia is a low-income country, with low electricity access (45%) and an inefficient power transmission network. The government aims to achieve universal access and become an electricity exporter in the region by 2025. This study provides an invaluable perspective on different aspects of Ethiopia’s energy transition, focusing on achieving universal access and covering the country’s electricity needs during 2015–2065. We co-developed and investigated three scenarios to examine the policy and technology levels available to the government to meet their national priorities. To conduct this analysis, we soft-linked OnSSET, a modelling tool used for geospatial analysis, with OSeMOSYS, a cost-optimization modelling tool used for medium to long-run energy planning. Our results show that the country needs to diversify its power generation system to achieve universal access and cover its future electricity needs by increasing its overall carbon dioxide emissions and fully exploit hydropower. With the aim of achieving universal access by 2025, the newly electrified population is supplied primarily by the grid (65%), followed by stand-alone (32%) technologies. Similarly, until 2065, most of the electrified people by 2025 will continue to be grid-connected (99%). The country’s exports will increase to 17 TWh by 2065, up from 832 GWh in 2015, leading to a cumulative rise in electricity export revenues of 184 billion USD.</jats:p>',
#  'DOI': '10.3390/en14041209',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2021, 2, 23]],
#   'date-time': '2021-02-23T17:40:16Z',
#   'timestamp': 1614102016000},
#  'page': '1209',
#  'source': 'Crossref',
#  'is-referenced-by-count': 23,
#  'title': ['Influence of Electrification Pathways in the Electricity Sector of Ethiopia—Policy Implications Linking Spatial Electrification Analysis and Medium to Long-Term Energy Planning'],
#  'prefix': '10.3390',
#  'volume': '14',
#  'author': [{'ORCID': 'http://orcid.org/0000-0001-7537-5470',
#    'authenticated-orcid': False,
#    'given': 'Ioannis',
#    'family': 'Pappis',
#    'sequence': 'first',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0002-1565-2752',
#    'authenticated-orcid': False,
#    'given': 'Andreas',
#    'family': 'Sahlberg',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Tewodros',
#    'family': 'Walle',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0002-6179-927X',
#    'authenticated-orcid': False,
#    'given': 'Oliver',
#    'family': 'Broad',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0001-8801-9686',
#    'authenticated-orcid': False,
#    'given': 'Elusiyan',
#    'family': 'Eludoyin',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Mark',
#    'family': 'Howells',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0001-9367-1791',
#    'authenticated-orcid': False,
#    'given': 'Will',
#    'family': 'Usher',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'member': '1968',
#  'published-online': {'date-parts': [[2021, 2, 23]]},
#  'reference': [{'key': 'ref1',
#    'unstructured': 'Goal 7: Ensure Access to Affordable, Reliable, Sustainable and Modern Energy for All—SDG Indicatorshttps://unstats.un.org/sdgs/report/2016/goal-07/'},
#   {'key': 'ref2',
#    'series-title': 'Global Energy Assessment—Toward a Sustainable Future',
#    'article-title': 'Energy, Poverty, and Development',
#    'author': 'Karekezi',
#    'year': '2012'},
#   {'key': 'ref3',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.rser.2015.03.058'},
#   {'key': 'ref4',
#    'unstructured': 'Access to Electricity—SDG7: Data and Projections—Analysishttps://www.iea.org/reports/sdg7-data-and-projections/access-to-electricity'},
#   {'key': 'ref5',
#    'unstructured': 'World Population Prospects—Population Division—United Nationshttps://population.un.org/wpp/'},
#   {'key': 'ref6',
#    'unstructured': 'World Bank Open Datahttps://data.worldbank.org/'},
#   {'key': 'ref7',
#    'unstructured': 'The World Bank in Middle Income Countrieshttps://www.worldbank.org/en/country/mic/overview'},
#   {'key': 'ref8',
#    'unstructured': 'Ethiopia—GNI per Capitahttps://www.indexmundi.com/facts/ethiopia/gni-per-capita'},
#   {'key': 'ref9',
#    'unstructured': 'World Development Indicatorshttps://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?locations=ZG'},
#   {'key': 'ref10',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2019.04.095'},
#   {'key': 'ref11',
#    'series-title': 'Output-Based Aid in Ethiopia: Dealing with the ‘Last Mile’ Paradox in Rural Electrification. OBApproaches',
#    'author': 'Maurer',
#    'year': '2009'},
#   {'key': 'ref12',
#    'series-title': 'Energy Transition Strategies: Ethiopia’s Low-Carbon Development Pathway',
#    'author': 'Tsafos',
#    'year': '2020'},
#   {'key': 'ref13',
#    'series-title': 'World Energy Balances 2019',
#    'year': '2019'},
#   {'key': 'ref14',
#    'unstructured': 'Growth and Transformation Plan II (GTP II) (2015/16-2019/20)http://www.undp.org/content/dam/dagethiopia/documents/GTP%20II%20MIDTERM%20REV%20Summarized%20%2012%2011%20%202018%20final_2.pdf'},
#   {'key': 'ref15',
#    'unstructured': 'Ethiopia’s Climate-Resilient Green Economyhttps://www4.unfccc.int/sites/NAPC/Documents/Parties/Final%20Ethiopia-national-adaptation-plan%20%281%29.pdf'},
#   {'key': 'ref16',
#    'unstructured': 'Intended Nationally Determined Contribution (INDC) of the Federal Democratic Republic of Ethiopiahttps://www4.unfccc.int/sites/ndcstaging/PublishedDocuments/Ethiopia%20First/INDC-Ethiopia-100615.pdf'},
#   {'key': 'ref17',
#    'unstructured': 'National Electrification Program 2.0https://minigrids.org/wp-content/uploads/2019/04/Ethiopia-2.0.pdf'},
#   {'key': 'ref18',
#    'unstructured': 'The World Bankhttps://data.worldbank.org/indicator/EG.USE.ELEC.KH.PC?most_recent_value_desc=true'},
#   {'key': 'ref19',
#    'unstructured': 'Riders on the Storm: Ethiopia Bids to Become Wind Capital of Africahttps://www.cnn.com/2016/12/20/africa/ethiopia-wind-power/index.html'},
#   {'key': 'ref20',
#    'unstructured': 'World Energy Balanceshttps://www.oecd-ilibrary.org/energy/data/iea-world-energy-statistics-and-balances/world-energy-balances_data-00512-en'},
#   {'key': 'ref21',
#    'unstructured': 'Electricity/Energy Tariff Adjustment in Ethiopia (Effective as of December 2018 and the Adjustment Is to Be Continued to Dec 2021. Ethiopian Energy and Power Business Portalhttps://ethioenergybuz.com/en/blog/264-electricity-energy-tariff-in-ethiopia-current'},
#   {'key': 'ref22',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/s41467-018-08275-7'},
#   {'key': 'ref23',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.enpol.2015.05.013'},
#   {'key': 'ref24',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.enpol.2012.10.066'},
#   {'key': 'ref25',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/0166-0462(80)90034-4'},
#   {'key': 'ref26',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2015.11.068'},
#   {'key': 'ref27',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/ijgi3020662'},
#   {'key': 'ref28',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apgeog.2016.04.009'},
#   {'key': 'ref29',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2009.06.006'},
#   {'key': 'ref30',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2011.11.059'},
#   {'key': 'ref31',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1088/1748-9326/aa7b29'},
#   {'key': 'ref32',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2017.07.144'},
#   {'key': 'ref33',
#    'series-title': 'Towards Universal Electricity Access in Sub-Saharan Africa: A Quantitative Analysis of Technology and Investment Requirements',
#    'first-page': '58',
#    'author': 'Lucas',
#    'year': '2017'},
#   {'key': 'ref34',
#    'series-title': 'Energy Projections for African Countries',
#    'author': 'Pappis',
#    'year': '2019'},
#   {'key': 'ref35'},
#   {'key': 'ref36',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2011.11.037'},
#   {'key': 'ref37',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s10287-007-0046-z'},
#   {'key': 'ref38',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s10666-018-9627-1'},
#   {'key': 'ref39',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2018.02.067'},
#   {'key': 'ref40',
#    'series-title': 'LEAP: The Low Emissions Analysis Platform',
#    'year': '2012'},
#   {'key': 'ref41',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1080/17565529.2018.1442800'},
#   {'key': 'ref42',
#    'series-title': 'Agenda 2063: The Africa We Want',
#    'year': '2015'},
#   {'key': 'ref43',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.enpol.2011.06.033'},
#   {'key': 'ref44',
#    'unstructured': 'OnSSET, Open-Source Spatial Electrification Toolhttp://www.onsset.org/'},
#   {'key': 'ref45', 'doi-asserted-by': 'publisher', 'DOI': '10.1038/542393a'},
#   {'key': 'ref46',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1186/s13705-018-0154-3'},
#   {'key': 'ref47',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.rser.2007.01.007'},
#   {'key': 'ref48',
#    'series-title': 'Mainstreaming Sustainable Energy Access into National Development Planning: The Case of Ethiopia',
#    'author': 'Aragaw',
#    'year': '2013'},
#   {'key': 'ref49',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1088/1748-9326/aa7e18'},
#   {'key': 'ref50',
#    'series-title': 'World Sustainability Series',
#    'doi-asserted-by': 'crossref',
#    'first-page': '335',
#    'DOI': '10.1007/978-3-319-26734-0_21',
#    'article-title': 'Engaging Stakeholders for Sustainable Development',
#    'author': 'Filho',
#    'year': '2016'},
#   {'key': 'ref51',
#    'unstructured': 'Energy Modelling Toolshttps://www.iaea.org/topics/energy-planning/energy-modelling-tools'},
#   {'key': 'ref52',
#    'unstructured': 'UNDP and UNDESA, UN Modelling Toolshttps://un-modelling.github.io/modelling-tools/'},
#   {'key': 'ref53',
#    'unstructured': 'Energypedia, Open Energy System Modelshttps://energypedia.info/wiki/Open_Energy_System_Models'},
#   {'key': 'ref54',
#    'unstructured': 'Planning for the Renewable Future: Long-Term Modelling and Tools to Expand Variable Renewable Power in Emerging Economieshttp://biblioteca.olade.org/opac-tmpl/Documentos/cg00543.pdf'},
#   {'key': 'ref55',
#    'series-title': 'Classification of Energy Models',
#    'volume': 'Volume 777',
#    'author': 'Van Beeck',
#    'year': '2019'},
#   {'key': 'ref56',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.rser.2004.09.004'},
#   {'key': 'ref57',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.eneco.2007.03.004'},
#   {'key': 'ref58',
#    'series-title': 'Advances in Spatial Science',
#    'doi-asserted-by': 'crossref',
#    'first-page': '57',
#    'DOI': '10.1007/978-3-662-04853-5_5',
#    'article-title': 'General Modelling Approaches: Top-Down or Bottom-Up?',
#    'author': 'Worsley',
#    'year': '2002'},
#   {'key': 'ref59',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/S0140-9883(98)00002-4'},
#   {'key': 'ref60',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.enpol.2018.01.045'},
#   {'key': 'ref61',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/en10101468'},
#   {'key': 'ref62',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.esd.2015.12.001'},
#   {'key': 'ref63',
#    'unstructured': 'Global Climate, Land, Energy & Water Strategies (CLEWS)https://unite.un.org/sites/unite.un.org/files/app-globalclews-v-1-0/landingpage.html'},
#   {'key': 'ref64',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.esr.2018.03.005'},
#   {'key': 'ref65',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/en12071395'},
#   {'key': 'ref66',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2020.114749'},
#   {'key': 'ref67',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/su12030777'},
#   {'key': 'ref68',
#    'unstructured': 'World Energy Outlook 2019https://www.iea.org/reports/world-energy-outlook-2019'},
#   {'key': 'ref69',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1111/1468-2451.00049'},
#   {'key': 'ref70'},
#   {'key': 'ref71',
#    'unstructured': 'Renewables.ninjahttps://www.renewables.ninja/'},
#   {'key': 'ref72',
#    'unstructured': 'Energy Supply Technologies Datahttps://iea-etsap.org/index.php/energy-technology-data/energy-supply-technologies-data'},
#   {'key': 'ref73',
#    'series-title': 'Beyond Connections: Energy Access Redefined. ESMAP Technical Report',
#    'author': 'Bhatia',
#    'year': '2015'},
#   {'key': 'ref74',
#    'unstructured': 'GitHub Repository—Ethiopia Studyhttps://github.com/JoPapp/Ethiopia-study'},
#   {'key': 'ref75',
#    'unstructured': 'Platts-World Electric Power Plants Databasehttps://www.spglobal.com/platts/en/products-services/market-conditions'},
#   {'key': 'ref76',
#    'series-title': 'The Great Shift: Macroeconomic Projections for the World Economy at the 2050 Horizon',
#    'author': 'Fouré',
#    'year': '2012'},
#   {'key': 'ref77',
#    'series-title': 'World Population Prospects 2019',
#    'year': '2019'},
#   {'key': 'ref78',
#    'series-title': 'World Urbanization Prospects: The 2018 Revision',
#    'year': '2019'},
#   {'key': 'ref79',
#    'series-title': 'USAID, Grid Management Support Program, System Integration Study, (GMSP-SIS) Power Africa: Ethiopia, Power Africa Transactions and Reforms Program (PATRP)',
#    'year': '2019'},
#   {'key': 'ref80',
#    'series-title': 'Africa Energy Outlook: A Focus on Energy Prospects in Sub-Saharan Africa',
#    'year': '2014'},
#   {'key': 'ref81',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.energy.2007.07.012'},
#   {'key': 'ref82',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.rser.2005.06.002'},
#   {'key': 'ref83',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.17159/2413-3051/2010/v21i1a3246'},
#   {'key': 'ref84',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2017.03.001'},
#   {'key': 'ref85',
#    'unstructured': 'World Energy Outlook 2020https://www.iea.org/reports/world-energy-outlook-2020'},
#   {'key': 'ref86',
#    'series-title': 'World Energy Assessment: Energy and the Challenge of Sustainability',
#    'article-title': 'Energy Policies for Sustainable Development',
#    'volume': 'Volume 12',
#    'author': 'Jefferson',
#    'year': '2000'},
#   {'key': 'ref87',
#    'unstructured': 'Nile Dam row: Egypt Fumes as Ethiopia Celebrateshttps://www.bbc.com/news/world-africa-53573154'},
#   {'key': 'ref88',
#    'unstructured': 'Egypt-Ethiopia Row: The Trouble over a Giant Nile Damhttps://www.bbc.com/news/world-africa-50328647'},
#   {'key': 'ref89',
#    'series-title': 'Society and Nuclear Energy: Towards a Better Understanding',
#    'year': '2002'},
#   {'key': 'ref90',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/su12051793'},
#   {'key': 'ref91',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2020.115171'},
#   {'key': 'ref92',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.esr.2017.11.001'},
#   {'key': 'ref93',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1111/j.1467-9361.2012.00675.x'},
#   {'key': 'ref94',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apenergy.2016.08.106'},
#   {'key': 'ref95',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1108/IJESM-04-2015-0005'},
#   {'key': 'ref96',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1111/j.1467-9361.2012.00676.x'},
#   {'key': 'ref97',
#    'unstructured': 'Tackling the Impacts of COVID-19 is Imperative to Ethiopia’s Journey to Prosperityhttps://blogs.worldbank.org/africacan/tackling-impacts-covid-19-imperative-ethiopias-journey-prosperity'},
#   {'key': 'ref98',
#    'unstructured': 'COVID-19—Topicshttps://www.iea.org/topics/covid-19'},
#   {'key': 'ref99',
#    'unstructured': 'The Covid-19 Crisis Is Reversing Progress on Energy Access in Africa—Analysishttps://www.iea.org/articles/the-covid-19-crisis-is-reversing-progress-on-energy-access-in-africa'},
#   {'key': 'ref100',
#    'unstructured': 'Global Solar Atlashttps://globalsolaratlas.info/map'},
#   {'key': 'ref101',
#    'unstructured': 'Global Wind Atlashttps://globalwindatlas.info'},
#   {'key': 'ref102',
#    'unstructured': 'IEAhttps://www.iea.org/reports/world-energy-outlook-2018'},
#   {'key': 'ref103',
#    'series-title': 'Planning and Prospects for Renewable Power: West Africa',
#    'year': '2018'},
#   {'key': 'ref104',
#    'unstructured': 'Projected Costs of Generating Electricity, 2015 Editionhttps://www.iea.org/reports/projected-costs-of-generating-electricity-2015'}],
#  'container-title': ['Energies'],
#  'original-title': [],
#  'language': 'en',
#  'link': [{'URL': 'https://www.mdpi.com/1996-1073/14/4/1209/pdf',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2021, 2, 25]],
#   'date-time': '2021-02-25T10:55:30Z',
#   'timestamp': 1614250530000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://www.mdpi.com/1996-1073/14/4/1209'}},
#  'subtitle': [],
#  'short-title': [],
#  'issued': {'date-parts': [[2021, 2, 23]]},
#  'references-count': 104,
#  'journal-issue': {'issue': '4',
#   'published-online': {'date-parts': [[2021, 2]]}},
#  'alternative-id': ['en14041209'],
#  'URL': 'http://dx.doi.org/10.3390/en14041209',
#  'relation': {},
#  'ISSN': ['1996-1073'],
#  'issn-type': [{'value': '1996-1073', 'type': 'electronic'}],
#  'subject': ['Energy (miscellaneous)',
#   'Energy Engineering and Power Technology',
#   'Renewable Energy, Sustainability and the Environment',
#   'Electrical and Electronic Engineering',
#   'Control and Optimization',
#   'Engineering (miscellaneous)'],
#  'published': {'date-parts': [[2021, 2, 23]]}}

# %%
from habanero import Crossref
cr = Crossref()
cr.works(ids = doi)
# Out:
# {'status': 'ok',
#  'message-type': 'work',
#  'message-version': '1.0.0',
#  'message': {'indexed': {'date-parts': [[2024, 2, 16]],
#    'date-time': '2024-02-16T23:28:22Z',
#    'timestamp': 1708126102284},
#   'reference-count': 104,
#   'publisher': 'MDPI AG',
#   'issue': '4',
#   'license': [{'start': {'date-parts': [[2021, 2, 23]],
#      'date-time': '2021-02-23T00:00:00Z',
#      'timestamp': 1614038400000},
#     'content-version': 'vor',
#     'delay-in-days': 0,
#     'URL': 'https://creativecommons.org/licenses/by/4.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Energies'],
#   'abstract': '<jats:p>Ethiopia is a low-income country, with low electricity access (45%) and an inefficient power transmission network. The government aims to achieve universal access and become an electricity exporter in the region by 2025. This study provides an invaluable perspective on different aspects of Ethiopia’s energy transition, focusing on achieving universal access and covering the country’s electricity needs during 2015–2065. We co-developed and investigated three scenarios to examine the policy and technology levels available to the government to meet their national priorities. To conduct this analysis, we soft-linked OnSSET, a modelling tool used for geospatial analysis, with OSeMOSYS, a cost-optimization modelling tool used for medium to long-run energy planning. Our results show that the country needs to diversify its power generation system to achieve universal access and cover its future electricity needs by increasing its overall carbon dioxide emissions and fully exploit hydropower. With the aim of achieving universal access by 2025, the newly electrified population is supplied primarily by the grid (65%), followed by stand-alone (32%) technologies. Similarly, until 2065, most of the electrified people by 2025 will continue to be grid-connected (99%). The country’s exports will increase to 17 TWh by 2065, up from 832 GWh in 2015, leading to a cumulative rise in electricity export revenues of 184 billion USD.</jats:p>',
#   'DOI': '10.3390/en14041209',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2021, 2, 23]],
#    'date-time': '2021-02-23T17:40:16Z',
#    'timestamp': 1614102016000},
#   'page': '1209',
#   'source': 'Crossref',
#   'is-referenced-by-count': 23,
#   'title': ['Influence of Electrification Pathways in the Electricity Sector of Ethiopia—Policy Implications Linking Spatial Electrification Analysis and Medium to Long-Term Energy Planning'],
#   'prefix': '10.3390',
#   'volume': '14',
#   'author': [{'ORCID': 'http://orcid.org/0000-0001-7537-5470',
#     'authenticated-orcid': False,
#     'given': 'Ioannis',
#     'family': 'Pappis',
#     'sequence': 'first',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0002-1565-2752',
#     'authenticated-orcid': False,
#     'given': 'Andreas',
#     'family': 'Sahlberg',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Tewodros',
#     'family': 'Walle',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0002-6179-927X',
#     'authenticated-orcid': False,
#     'given': 'Oliver',
#     'family': 'Broad',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0001-8801-9686',
#     'authenticated-orcid': False,
#     'given': 'Elusiyan',
#     'family': 'Eludoyin',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Mark',
#     'family': 'Howells',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0001-9367-1791',
#     'authenticated-orcid': False,
#     'given': 'Will',
#     'family': 'Usher',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '1968',
#   'published-online': {'date-parts': [[2021, 2, 23]]},
#   'reference': [{'key': 'ref1',
#     'unstructured': 'Goal 7: Ensure Access to Affordable, Reliable, Sustainable and Modern Energy for All—SDG Indicatorshttps://unstats.un.org/sdgs/report/2016/goal-07/'},
#    {'key': 'ref2',
#     'series-title': 'Global Energy Assessment—Toward a Sustainable Future',
#     'article-title': 'Energy, Poverty, and Development',
#     'author': 'Karekezi',
#     'year': '2012'},
#    {'key': 'ref3',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.rser.2015.03.058'},
#    {'key': 'ref4',
#     'unstructured': 'Access to Electricity—SDG7: Data and Projections—Analysishttps://www.iea.org/reports/sdg7-data-and-projections/access-to-electricity'},
#    {'key': 'ref5',
#     'unstructured': 'World Population Prospects—Population Division—United Nationshttps://population.un.org/wpp/'},
#    {'key': 'ref6',
#     'unstructured': 'World Bank Open Datahttps://data.worldbank.org/'},
#    {'key': 'ref7',
#     'unstructured': 'The World Bank in Middle Income Countrieshttps://www.worldbank.org/en/country/mic/overview'},
#    {'key': 'ref8',
#     'unstructured': 'Ethiopia—GNI per Capitahttps://www.indexmundi.com/facts/ethiopia/gni-per-capita'},
#    {'key': 'ref9',
#     'unstructured': 'World Development Indicatorshttps://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?locations=ZG'},
#    {'key': 'ref10',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2019.04.095'},
#    {'key': 'ref11',
#     'series-title': 'Output-Based Aid in Ethiopia: Dealing with the ‘Last Mile’ Paradox in Rural Electrification. OBApproaches',
#     'author': 'Maurer',
#     'year': '2009'},
#    {'key': 'ref12',
#     'series-title': 'Energy Transition Strategies: Ethiopia’s Low-Carbon Development Pathway',
#     'author': 'Tsafos',
#     'year': '2020'},
#    {'key': 'ref13',
#     'series-title': 'World Energy Balances 2019',
#     'year': '2019'},
#    {'key': 'ref14',
#     'unstructured': 'Growth and Transformation Plan II (GTP II) (2015/16-2019/20)http://www.undp.org/content/dam/dagethiopia/documents/GTP%20II%20MIDTERM%20REV%20Summarized%20%2012%2011%20%202018%20final_2.pdf'},
#    {'key': 'ref15',
#     'unstructured': 'Ethiopia’s Climate-Resilient Green Economyhttps://www4.unfccc.int/sites/NAPC/Documents/Parties/Final%20Ethiopia-national-adaptation-plan%20%281%29.pdf'},
#    {'key': 'ref16',
#     'unstructured': 'Intended Nationally Determined Contribution (INDC) of the Federal Democratic Republic of Ethiopiahttps://www4.unfccc.int/sites/ndcstaging/PublishedDocuments/Ethiopia%20First/INDC-Ethiopia-100615.pdf'},
#    {'key': 'ref17',
#     'unstructured': 'National Electrification Program 2.0https://minigrids.org/wp-content/uploads/2019/04/Ethiopia-2.0.pdf'},
#    {'key': 'ref18',
#     'unstructured': 'The World Bankhttps://data.worldbank.org/indicator/EG.USE.ELEC.KH.PC?most_recent_value_desc=true'},
#    {'key': 'ref19',
#     'unstructured': 'Riders on the Storm: Ethiopia Bids to Become Wind Capital of Africahttps://www.cnn.com/2016/12/20/africa/ethiopia-wind-power/index.html'},
#    {'key': 'ref20',
#     'unstructured': 'World Energy Balanceshttps://www.oecd-ilibrary.org/energy/data/iea-world-energy-statistics-and-balances/world-energy-balances_data-00512-en'},
#    {'key': 'ref21',
#     'unstructured': 'Electricity/Energy Tariff Adjustment in Ethiopia (Effective as of December 2018 and the Adjustment Is to Be Continued to Dec 2021. Ethiopian Energy and Power Business Portalhttps://ethioenergybuz.com/en/blog/264-electricity-energy-tariff-in-ethiopia-current'},
#    {'key': 'ref22',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/s41467-018-08275-7'},
#    {'key': 'ref23',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.enpol.2015.05.013'},
#    {'key': 'ref24',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.enpol.2012.10.066'},
#    {'key': 'ref25',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/0166-0462(80)90034-4'},
#    {'key': 'ref26',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2015.11.068'},
#    {'key': 'ref27',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3390/ijgi3020662'},
#    {'key': 'ref28',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apgeog.2016.04.009'},
#    {'key': 'ref29',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2009.06.006'},
#    {'key': 'ref30',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2011.11.059'},
#    {'key': 'ref31',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1088/1748-9326/aa7b29'},
#    {'key': 'ref32',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2017.07.144'},
#    {'key': 'ref33',
#     'series-title': 'Towards Universal Electricity Access in Sub-Saharan Africa: A Quantitative Analysis of Technology and Investment Requirements',
#     'first-page': '58',
#     'author': 'Lucas',
#     'year': '2017'},
#    {'key': 'ref34',
#     'series-title': 'Energy Projections for African Countries',
#     'author': 'Pappis',
#     'year': '2019'},
#    {'key': 'ref35'},
#    {'key': 'ref36',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2011.11.037'},
#    {'key': 'ref37',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1007/s10287-007-0046-z'},
#    {'key': 'ref38',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1007/s10666-018-9627-1'},
#    {'key': 'ref39',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2018.02.067'},
#    {'key': 'ref40',
#     'series-title': 'LEAP: The Low Emissions Analysis Platform',
#     'year': '2012'},
#    {'key': 'ref41',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1080/17565529.2018.1442800'},
#    {'key': 'ref42',
#     'series-title': 'Agenda 2063: The Africa We Want',
#     'year': '2015'},
#    {'key': 'ref43',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.enpol.2011.06.033'},
#    {'key': 'ref44',
#     'unstructured': 'OnSSET, Open-Source Spatial Electrification Toolhttp://www.onsset.org/'},
#    {'key': 'ref45', 'doi-asserted-by': 'publisher', 'DOI': '10.1038/542393a'},
#    {'key': 'ref46',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1186/s13705-018-0154-3'},
#    {'key': 'ref47',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.rser.2007.01.007'},
#    {'key': 'ref48',
#     'series-title': 'Mainstreaming Sustainable Energy Access into National Development Planning: The Case of Ethiopia',
#     'author': 'Aragaw',
#     'year': '2013'},
#    {'key': 'ref49',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1088/1748-9326/aa7e18'},
#    {'key': 'ref50',
#     'series-title': 'World Sustainability Series',
#     'doi-asserted-by': 'crossref',
#     'first-page': '335',
#     'DOI': '10.1007/978-3-319-26734-0_21',
#     'article-title': 'Engaging Stakeholders for Sustainable Development',
#     'author': 'Filho',
#     'year': '2016'},
#    {'key': 'ref51',
#     'unstructured': 'Energy Modelling Toolshttps://www.iaea.org/topics/energy-planning/energy-modelling-tools'},
#    {'key': 'ref52',
#     'unstructured': 'UNDP and UNDESA, UN Modelling Toolshttps://un-modelling.github.io/modelling-tools/'},
#    {'key': 'ref53',
#     'unstructured': 'Energypedia, Open Energy System Modelshttps://energypedia.info/wiki/Open_Energy_System_Models'},
#    {'key': 'ref54',
#     'unstructured': 'Planning for the Renewable Future: Long-Term Modelling and Tools to Expand Variable Renewable Power in Emerging Economieshttp://biblioteca.olade.org/opac-tmpl/Documentos/cg00543.pdf'},
#    {'key': 'ref55',
#     'series-title': 'Classification of Energy Models',
#     'volume': 'Volume 777',
#     'author': 'Van Beeck',
#     'year': '2019'},
#    {'key': 'ref56',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.rser.2004.09.004'},
#    {'key': 'ref57',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.eneco.2007.03.004'},
#    {'key': 'ref58',
#     'series-title': 'Advances in Spatial Science',
#     'doi-asserted-by': 'crossref',
#     'first-page': '57',
#     'DOI': '10.1007/978-3-662-04853-5_5',
#     'article-title': 'General Modelling Approaches: Top-Down or Bottom-Up?',
#     'author': 'Worsley',
#     'year': '2002'},
#    {'key': 'ref59',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/S0140-9883(98)00002-4'},
#    {'key': 'ref60',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.enpol.2018.01.045'},
#    {'key': 'ref61',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3390/en10101468'},
#    {'key': 'ref62',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.esd.2015.12.001'},
#    {'key': 'ref63',
#     'unstructured': 'Global Climate, Land, Energy & Water Strategies (CLEWS)https://unite.un.org/sites/unite.un.org/files/app-globalclews-v-1-0/landingpage.html'},
#    {'key': 'ref64',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.esr.2018.03.005'},
#    {'key': 'ref65',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3390/en12071395'},
#    {'key': 'ref66',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2020.114749'},
#    {'key': 'ref67',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3390/su12030777'},
#    {'key': 'ref68',
#     'unstructured': 'World Energy Outlook 2019https://www.iea.org/reports/world-energy-outlook-2019'},
#    {'key': 'ref69',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/1468-2451.00049'},
#    {'key': 'ref70'},
#    {'key': 'ref71',
#     'unstructured': 'Renewables.ninjahttps://www.renewables.ninja/'},
#    {'key': 'ref72',
#     'unstructured': 'Energy Supply Technologies Datahttps://iea-etsap.org/index.php/energy-technology-data/energy-supply-technologies-data'},
#    {'key': 'ref73',
#     'series-title': 'Beyond Connections: Energy Access Redefined. ESMAP Technical Report',
#     'author': 'Bhatia',
#     'year': '2015'},
#    {'key': 'ref74',
#     'unstructured': 'GitHub Repository—Ethiopia Studyhttps://github.com/JoPapp/Ethiopia-study'},
#    {'key': 'ref75',
#     'unstructured': 'Platts-World Electric Power Plants Databasehttps://www.spglobal.com/platts/en/products-services/market-conditions'},
#    {'key': 'ref76',
#     'series-title': 'The Great Shift: Macroeconomic Projections for the World Economy at the 2050 Horizon',
#     'author': 'Fouré',
#     'year': '2012'},
#    {'key': 'ref77',
#     'series-title': 'World Population Prospects 2019',
#     'year': '2019'},
#    {'key': 'ref78',
#     'series-title': 'World Urbanization Prospects: The 2018 Revision',
#     'year': '2019'},
#    {'key': 'ref79',
#     'series-title': 'USAID, Grid Management Support Program, System Integration Study, (GMSP-SIS) Power Africa: Ethiopia, Power Africa Transactions and Reforms Program (PATRP)',
#     'year': '2019'},
#    {'key': 'ref80',
#     'series-title': 'Africa Energy Outlook: A Focus on Energy Prospects in Sub-Saharan Africa',
#     'year': '2014'},
#    {'key': 'ref81',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.energy.2007.07.012'},
#    {'key': 'ref82',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.rser.2005.06.002'},
#    {'key': 'ref83',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.17159/2413-3051/2010/v21i1a3246'},
#    {'key': 'ref84',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2017.03.001'},
#    {'key': 'ref85',
#     'unstructured': 'World Energy Outlook 2020https://www.iea.org/reports/world-energy-outlook-2020'},
#    {'key': 'ref86',
#     'series-title': 'World Energy Assessment: Energy and the Challenge of Sustainability',
#     'article-title': 'Energy Policies for Sustainable Development',
#     'volume': 'Volume 12',
#     'author': 'Jefferson',
#     'year': '2000'},
#    {'key': 'ref87',
#     'unstructured': 'Nile Dam row: Egypt Fumes as Ethiopia Celebrateshttps://www.bbc.com/news/world-africa-53573154'},
#    {'key': 'ref88',
#     'unstructured': 'Egypt-Ethiopia Row: The Trouble over a Giant Nile Damhttps://www.bbc.com/news/world-africa-50328647'},
#    {'key': 'ref89',
#     'series-title': 'Society and Nuclear Energy: Towards a Better Understanding',
#     'year': '2002'},
#    {'key': 'ref90',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3390/su12051793'},
#    {'key': 'ref91',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2020.115171'},
#    {'key': 'ref92',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.esr.2017.11.001'},
#    {'key': 'ref93',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.1467-9361.2012.00675.x'},
#    {'key': 'ref94',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.apenergy.2016.08.106'},
#    {'key': 'ref95',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1108/IJESM-04-2015-0005'},
#    {'key': 'ref96',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.1467-9361.2012.00676.x'},
#    {'key': 'ref97',
#     'unstructured': 'Tackling the Impacts of COVID-19 is Imperative to Ethiopia’s Journey to Prosperityhttps://blogs.worldbank.org/africacan/tackling-impacts-covid-19-imperative-ethiopias-journey-prosperity'},
#    {'key': 'ref98',
#     'unstructured': 'COVID-19—Topicshttps://www.iea.org/topics/covid-19'},
#    {'key': 'ref99',
#     'unstructured': 'The Covid-19 Crisis Is Reversing Progress on Energy Access in Africa—Analysishttps://www.iea.org/articles/the-covid-19-crisis-is-reversing-progress-on-energy-access-in-africa'},
#    {'key': 'ref100',
#     'unstructured': 'Global Solar Atlashttps://globalsolaratlas.info/map'},
#    {'key': 'ref101',
#     'unstructured': 'Global Wind Atlashttps://globalwindatlas.info'},
#    {'key': 'ref102',
#     'unstructured': 'IEAhttps://www.iea.org/reports/world-energy-outlook-2018'},
#    {'key': 'ref103',
#     'series-title': 'Planning and Prospects for Renewable Power: West Africa',
#     'year': '2018'},
#    {'key': 'ref104',
#     'unstructured': 'Projected Costs of Generating Electricity, 2015 Editionhttps://www.iea.org/reports/projected-costs-of-generating-electricity-2015'}],
#   'container-title': ['Energies'],
#   'original-title': [],
#   'language': 'en',
#   'link': [{'URL': 'https://www.mdpi.com/1996-1073/14/4/1209/pdf',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2021, 2, 25]],
#    'date-time': '2021-02-25T10:55:30Z',
#    'timestamp': 1614250530000},
#   'score': 1,
#   'resource': {'primary': {'URL': 'https://www.mdpi.com/1996-1073/14/4/1209'}},
#   'subtitle': [],
#   'short-title': [],
#   'issued': {'date-parts': [[2021, 2, 23]]},
#   'references-count': 104,
#   'journal-issue': {'issue': '4',
#    'published-online': {'date-parts': [[2021, 2]]}},
#   'alternative-id': ['en14041209'],
#   'URL': 'http://dx.doi.org/10.3390/en14041209',
#   'relation': {},
#   'ISSN': ['1996-1073'],
#   'issn-type': [{'value': '1996-1073', 'type': 'electronic'}],
#   'subject': ['Energy (miscellaneous)',
#    'Energy Engineering and Power Technology',
#    'Renewable Energy, Sustainability and the Environment',
#    'Electrical and Electronic Engineering',
#    'Control and Optimization',
#    'Engineering (miscellaneous)'],
#   'published': {'date-parts': [[2021, 2, 23]]}}}

# %%
from habanero import counts
counts.citation_count(doi=doi)
# Out:
# 23
