# %%
from re import match, search, compile, I
import requests
import xml.etree.ElementTree as etree

# %% [markdown]
# # Step 1 - Clean list of DOIs
#
# DOIs should be provided in a valid format, but often are entered as URLs,
# prepended by `https://doi.org`. Sometimes, urls to assets are provided which
# are not valid DOIs, and these should raise a warning, but otherwise be ignored.

# %%
# Read in a list of DOIs from a csv file
file_path = 'list_of_doi.csv'
with open(file_path, 'r') as csv_file:
    dois = []
    for line in csv_file:
        dois.append(line.strip())

# %%
# Use regex pattern from https://www.crossref.org/blog/dois-and-matching-regular-expressions/
pattern = compile("10.\d{4,9}\/[-._;()\/:A-Z0-9]+", I)

valid = []
# Iterate over the list of possible DOIs and return valid, otherwise raise a warning
for doi in dois:
    match = pattern.search(doi)
    if match:
#         print( f"{match.group()} is a valid DOI.")
        valid.append(match.group())
    else:
        print(f"{doi} is not a DOI.")

# %% [markdown]
# # Step 2 - Prepare query string

# %%
query = f"?format=json&doi={','.join(valid[0:20])}"
# query = f"?format=json&doi=10.1038/s41597-023-02529-w"

# %%
query
# Out:
# '?format=json&doi=10.1016/j.esr.2021.100799,10.21203/rs.3.rs-1160025/v1,10.5281/zenodo.4728143,10.5281/zenodo.4650810,10.5281/zenodo.4725486,10.5281/zenodo.4650986,10.5281/zenodo.4650942,10.5281/zenodo.4725445,10.5281/zenodo.4650822,10.5281/zenodo.4650968,10.5281/zenodo.4725466,10.5281/zenodo.4737634,10.5281/zenodo.4737640,10.5281/zenodo.4725462,10.5281/zenodo.4652804,10.5281/zenodo.4650904,10.5281/zenodo.4725456,10.5281/zenodo.4737638,10.5281/zenodo.4650876,10.5281/zenodo.4737642'

# %% [markdown]
# # Step 3 - Retrieve matching results from OpenAire

# %%
token = "eyJraWQiOiJvaWRjIiwiYWxnIjoiUlMyNTYifQ..MvF-81woYQa0nPcCUn_ZRiIUrvkUR5nUpqgQGBU9K_sYFUmGMzLlTJhSE3nMRXbvD6YKXrkwAgV7-jlw43w6K1JluczPRpuwdZKgUHMl93dvW27eMuWTsGiVfw5sApFHBsNNZ4WW3_HmT_AOLNNQ5AgTe26BqyPb0wuTaalW1C1KCKZ8adT79QjLqCqlF1ms4hNj_DJ2uAO2R9e7A9nVXxey1CLpm81Kx3OUl-NSFzfJCVQMN61IrTEQ5PHmibW1dWUgfZYoncMpeFUfEfcJXG1el63o4LHIqoqci91_o82cjPBYYj40-fsJvMH0KnYBYhCJ0J0Ap2CIHca0LT0vPw"
headers = { "Authorization": f"Bearer {token}" }

api_url = "https://api.openaire.eu/search/researchProducts"
response = requests.get(api_url + query, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.headers["Content-Type"]
# Out:
# 'application/json;charset=UTF-8'

# %%
response.json()
# Out:
# {'response': {'header': {'query': {'$': '(oaftype exact result) and ((pidclassid exact "doi" and pid exact "10.1016/j.esr.2021.100799") or (pidclassid exact "doi" and pid exact "10.21203/rs.3.rs-1160025/v1") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4728143") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650810") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4725486") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650986") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650942") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4725445") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650822") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650968") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4725466") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4737634") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4737640") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4725462") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4652804") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650904") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4725456") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4737638") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4650876") or (pidclassid exact "doi" and pid exact "10.5281/zenodo.4737642"))'},
#    'locale': {'$': 'en_US'},
#    'size': {'$': 10},
#    'page': {'$': 1},
#    'total': {'$': 20},
#    'fields': None},
#   'results': {'result': [{'header': {'dri:objIdentifier': {'$': 'doi_________::642e67d314304eb5dd5c5eb991372b4b'},
#       'dri:dateOfCollection': {'$': '2022-04-03T15:29:58Z'},
#       'dri:dateOfTransformation': None},
#      'metadata': {'oaf:entity': {'@xsi:schemaLocation': 'http://namespace.openaire.eu/oaf https://www.openaire.eu/schema/1.0/oaf-1.0.xsd',
#        'oaf:result': {'collectedfrom': [{'@name': 'Crossref',
#           '@id': 'openaire____::081b82f96300b6a6e3d282bad31cb6e2'},
#          {'@name': 'UnpayWall',
#           '@id': 'openaire____::8ac8380272269217cb09a928c8caa993'}],
#         'originalId': [{'$': '10.21203/rs.3.rs-1160025/v1'},
#          {'$': '50|doiboost____::642e67d314304eb5dd5c5eb991372b4b'}],
#         'pid': {'@classid': 'doi',
#          '@classname': 'Digital Object Identifier',
#          '@schemeid': 'dnet:pid_types',
#          '@schemename': 'dnet:pid_types',
#          '$': '10.21203/rs.3.rs-1160025/v1'},
#         'measure': [{'@id': 'influence',
#           '@score': '3.317285E-9',
#           '@class': 'C5'},
#          {'@id': 'popularity', '@score': '3.0997787E-9', '@class': 'C5'},
#          {'@id': 'influence_alt', '@score': '0', '@class': 'C5'},
#          {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'},
#          {'@id': 'impulse', '@score': '0', '@class': 'C5'}],
#         'title': {'@classid': 'main title',
#          '@classname': 'main title',
#          '@schemeid': 'dnet:dataCite_title',
#          '@schemename': 'dnet:dataCite_title',
#          '$': 'Future low-carbon electricity in Africa: how much material is needed?'},
#         'bestaccessright': {'@classid': 'OPEN',
#          '@classname': 'Open Access',
#          '@schemeid': 'dnet:access_modes',
#          '@schemename': 'dnet:access_modes'},
#         'creator': [{'@rank': '1',
#           '@name': 'Karla Cervantes',
#           '@surname': 'Barron',
#           '@orcid': '0000-0001-9185-3022',
#           '$': 'Karla Cervantes Barron'},
#          {'@rank': '2',
#           '@name': 'Maaike E',
#           '@surname': 'Hakker',
#           '$': 'Maaike E Hakker'},
#          {'@rank': '3',
#           '@name': 'Jonathan M',
#           '@surname': 'Cullen',
#           '@orcid': '0000-0003-4347-5025',
#           '$': 'Jonathan M Cullen'}],
#         'dateofacceptance': {'$': '2021-12-10'},
#         'description': {'$': '<jats:title>Abstract</jats:title>         <jats:p>African countries are expected to experience some of the worst climate effects, while trying to provide higher electricity access and increase wellbeing.Concrete, steel, and aluminium pre\xadsent the largest opportunities for action, given their high mass or embodied emissions projections.Embodied emissions related to material use for electricity plants are evaluated in three scenarios: a refer\xadence scenario, and two scenarios related to the Paris Agreement (where renewable energy increases), resulting in higher embodied emissions as renewables are integrated.Pursuing strategies to increase the use of renewables should be done along material efficiency strategies to reach the total low-carbon potential.</jats:p>'},
#         'language': {'@classid': 'und',
#          '@classname': 'Undetermined',
#          '@schemeid': 'dnet:languages',
#          '@schemename': 'dnet:languages'},
#         'relevantdate': [{'@classid': 'created',
#           '@classname': 'created',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '$': '2021-12-10'},
#          {'@classid': 'available',
#           '@classname': 'available',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '$': '2021-12-10'},
#          {'@classid': 'accepted',
#           '@classname': 'accepted',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '$': '2021-12-10'}],
#         'publisher': {'$': 'Research Square Platform LLC'},
#         'source': {'$': 'Crossref'},
#         'resulttype': {'@classid': 'publication',
#          '@classname': 'publication',
#          '@schemeid': 'dnet:result_typologies',
#          '@schemename': 'dnet:result_typologies'},
#         'resourcetype': {'@classid': '0016',
#          '@classname': 'Preprint',
#          '@schemeid': 'dnet:publication_resource',
#          '@schemename': 'dnet:publication_resource'},
#         'isgreen': {'$': False},
#         'openaccesscolor': {'$': 'hybrid'},
#         'isindiamondjournal': {'$': False},
#         'publiclyfunded': {'$': False},
#         'datainfo': {'inferred': {'$': False},
#          'deletedbyinference': {'$': False},
#          'trust': {'$': '0.9'},
#          'inferenceprovenance': {'$': 'null'},
#          'provenanceaction': {'@classid': 'sysimport:actionset',
#           '@classname': 'Harvested',
#           '@schemeid': 'dnet:provenanceActions',
#           '@schemename': 'dnet:provenanceActions'}},
#         'rels': {'rel': {'@inferred': True,
#           '@trust': '1.0',
#           '@inferenceprovenance': 'bip:affiliation:crossref',
#           '@provenanceaction': 'result:organization:bipinference',
#           'to': {'@class': 'hasAuthorInstitution',
#            '@scheme': 'dnet:result_organization_relations',
#            '@type': 'organization',
#            '$': 'openorgs____::b03ae6770284a0dfaca038c0f8193048'},
#           'country': {'@classid': 'GB',
#            '@classname': 'United Kingdom',
#            '@schemeid': 'dnet:countries',
#            '@schemename': 'dnet:countries'},
#           'legalshortname': {'$': 'University of Cambridge'},
#           'legalname': {'$': 'University of Cambridge'}}},
#         'children': {'instance': [{'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'UnpayWall',
#             '@id': 'openaire____::8ac8380272269217cb09a928c8caa993'},
#            'hostedby': {'@name': 'Unknown Repository',
#             '@id': 'openaire____::55045bd2a65019fd8e6741a755395c8c'},
#            'instancetype': {'@classid': '0016',
#             '@classname': 'Preprint',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '$': '10.21203/rs.3.rs-1160025/v1'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC BY'},
#            'webresource': {'url': {'$': 'https://www.researchsquare.com/article/rs-1160025/v1.pdf?c=1639181984000'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'Crossref',
#             '@id': 'openaire____::081b82f96300b6a6e3d282bad31cb6e2'},
#            'hostedby': {'@name': 'Unknown Repository',
#             '@id': 'openaire____::55045bd2a65019fd8e6741a755395c8c'},
#            'dateofacceptance': {'$': '2021-12-10'},
#            'instancetype': {'@classid': '0016',
#             '@classname': 'Preprint',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '$': '10.21203/rs.3.rs-1160025/v1'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC BY'},
#            'webresource': {'url': {'$': 'https://doi.org/10.21203/rs.3.rs-1160025/v1'}}}]}}}}},
#     {'header': {'dri:objIdentifier': {'$': 'doi_dedup___::ae34f1bc18ad7a467b581ff0f2a80011'},
#       'dri:dateOfCollection': {'$': '2021-12-03T10:07:45+0000'},
#       'dri:dateOfTransformation': {'$': '2021-12-03T10:07:45+0000'}},
#      'metadata': {'oaf:entity': {'@xsi:schemaLocation': 'http://namespace.openaire.eu/oaf https://www.openaire.eu/schema/1.0/oaf-1.0.xsd',
#        'oaf:result': {'collectedfrom': [{'@name': 'Datacite',
#           '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#          {'@name': 'ZENODO',
#           '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}],
#         'originalId': [{'$': '50|datacite____::ae34f1bc18ad7a467b581ff0f2a80011'},
#          {'$': '10.5281/zenodo.4728143'},
#          {'$': '50|datacite____::ecc0ff1534438608931d88cb2c9cf8b2'},
#          {'$': '10.5281/zenodo.7494341'},
#          {'$': 'oai:zenodo.org:4728144'},
#          {'$': '50|od______2659::3543950f730d05d4052c8dfd43779bd2'},
#          {'$': 'oai:zenodo.org:7512738'},
#          {'$': '50|od______2659::c2937b8bcab5046eee8884b0eaa5eded'},
#          {'$': '50|od______2659::10dc37b221e3f3d72535540102befb81'},
#          {'$': 'oai:zenodo.org:5751794'},
#          {'$': '50|od______2659::2f7553defd1eddd397dccda51d6a291f'},
#          {'$': 'oai:zenodo.org:4756748'},
#          {'$': 'oai:zenodo.org:7494342'},
#          {'$': '50|od______2659::15f463a5f22007997b9bee50bea3a104'},
#          {'$': '50|datacite____::06d6efd27ece7e6f70d9229a39931275'},
#          {'$': '10.5281/zenodo.7512737'},
#          {'$': 'oai:zenodo.org:5733317'},
#          {'$': '50|od______2659::e0160f93a9c4737e37da810926c5de10'}],
#         'pid': [{'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:actionset',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4728143'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:actionset',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.7494341'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4728144'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.7512738'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.5751794'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4756748'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.7494342'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:actionset',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.7512737'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.5733317'}],
#         'measure': [{'@id': 'influence',
#           '@score': '3.317285E-9',
#           '@class': 'C5'},
#          {'@id': 'popularity', '@score': '3.0997787E-9', '@class': 'C5'},
#          {'@id': 'influence_alt', '@score': '0', '@class': 'C5'},
#          {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'},
#          {'@id': 'impulse', '@score': '0', '@class': 'C5'},
#          {'@id': 'downloads', '@count': '946'},
#          {'@id': 'views', '@count': '680'}],
#         'title': {'@classid': 'main title',
#          '@classname': 'main title',
#          '@schemeid': 'dnet:dataCite_title',
#          '@schemename': 'dnet:dataCite_title',
#          '$': 'CCG Starter Data Kit: Algeria'},
#         'bestaccessright': {'@classid': 'OPEN',
#          '@classname': 'Open Access',
#          '@schemeid': 'dnet:access_modes',
#          '@schemename': 'dnet:access_modes'},
#         'creator': [{'@rank': '1',
#           '@name': 'Carla',
#           '@surname': 'Cannone',
#           '@orcid_pending': '0000-0002-1214-8913',
#           '$': 'Cannone, Carla'},
#          {'@rank': '2',
#           '@name': 'Lucy',
#           '@surname': 'Allington',
#           '@orcid_pending': '0000-0003-1801-899x',
#           '$': 'Allington, Lucy'},
#          {'@rank': '3',
#           '@name': 'Ioannis',
#           '@surname': 'Pappis',
#           '@orcid_pending': '0000-0001-7537-5470',
#           '$': 'Pappis, Ioannis'},
#          {'@rank': '4',
#           '@name': 'Karla',
#           '@surname': 'Cervantes Barron',
#           '@orcid_pending': '0000-0001-9185-3022',
#           '$': 'Cervantes Barron, Karla'},
#          {'@rank': '5',
#           '@name': 'Will',
#           '@surname': 'Usher',
#           '@orcid_pending': '0000-0001-9367-1791',
#           '$': 'Usher, Will'},
#          {'@rank': '6',
#           '@name': 'Steve',
#           '@surname': 'Pye',
#           '@orcid_pending': '0000-0003-1793-2552',
#           '$': 'Pye, Steve'},
#          {'@rank': '7',
#           '@name': 'Mark',
#           '@surname': 'Howells',
#           '@orcid_pending': '0000-0001-6419-4957',
#           '$': 'Howells, Mark'},
#          {'@rank': '8',
#           '@name': 'Miriam',
#           '@surname': 'Zachau Walker',
#           '@orcid_pending': '0000-0002-4757-3688',
#           '$': 'Zachau Walker, Miriam'},
#          {'@rank': '9',
#           '@name': 'Aniq',
#           '@surname': 'Ahsan',
#           '@orcid_pending': '0000-0002-6027-4818',
#           '$': 'Ahsan, Aniq'},
#          {'@rank': '10',
#           '@name': 'Flora',
#           '@surname': 'Charbonnier',
#           '@orcid_pending': '0000-0003-3174-0362',
#           '$': 'Charbonnier, Flora'},
#          {'@rank': '11',
#           '@name': 'Claire',
#           '@surname': 'Halloran',
#           '@orcid_pending': '0000-0002-0308-5623',
#           '$': 'Halloran, Claire'},
#          {'@rank': '12',
#           '@name': 'Stephanie',
#           '@surname': 'Hirmer',
#           '@orcid_pending': '0000-0001-7628-9259',
#           '$': 'Hirmer, Stephanie'},
#          {'@rank': '13',
#           '@name': 'Constantinos',
#           '@surname': 'Taliotis',
#           '@orcid': '0000-0003-4022-5506',
#           '$': 'Taliotis, Constantinos'},
#          {'@rank': '14',
#           '@name': 'Caroline',
#           '@surname': 'Sundin',
#           '$': 'Sundin, Caroline'},
#          {'@rank': '15',
#           '@name': 'Vignesh',
#           '@surname': 'Sridharan',
#           '@orcid_pending': '0000-0003-0764-2615',
#           '$': 'Sridharan, Vignesh'},
#          {'@rank': '16',
#           '@name': 'Eunice',
#           '@surname': 'Ramos',
#           '@orcid_pending': '0000-0001-9061-8485',
#           '$': 'Ramos, Eunice'},
#          {'@rank': '17',
#           '@name': 'Maarten',
#           '@surname': 'Brinkerink',
#           '@orcid_pending': '0000-0002-8980-9062',
#           '$': 'Brinkerink, Maarten'},
#          {'@rank': '18',
#           '@name': 'Paul',
#           '@surname': 'Deane',
#           '@orcid_pending': '0000-0002-4681-7791',
#           '$': 'Deane, Paul'},
#          {'@rank': '19',
#           '@name': 'Andrii',
#           '@surname': 'Gritsevskyi',
#           '$': 'Gritsevskyi, Andrii'},
#          {'@rank': '20',
#           '@name': 'Gustavo',
#           '@surname': 'Moura',
#           '$': 'Moura, Gustavo'},
#          {'@rank': '21',
#           '@name': 'Arnaud',
#           '@surname': 'Rouget',
#           '$': 'Rouget, Arnaud'},
#          {'@rank': '22',
#           '@name': 'David',
#           '@surname': 'Wogan',
#           '$': 'Wogan, David'},
#          {'@rank': '23',
#           '@name': 'Edito',
#           '@surname': 'Barcelona',
#           '$': 'Barcelona, Edito'},
#          {'@rank': '24',
#           '@name': 'Holger',
#           '@surname': 'Rogner',
#           '@orcid_pending': '0000-0002-1045-9830',
#           '$': 'Rogner, Holger'}],
#         'dateofacceptance': {'$': '2021-12-03'},
#         'description': {'$': '<p>A starter data kit for Algeria</p>'},
#         'subject': [{'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'GNUMathProg'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'energy system modelling'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'Algeria'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'linear programming'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'GLPK'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'OSeMOSYS'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'clicSAND'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': 'energy'},
#          {'@classid': 'keyword',
#           '@classname': 'keyword',
#           '@schemeid': 'dnet:subject_classification_typologies',
#           '@schemename': 'dnet:subject_classification_typologies',
#           '$': '#CCG'}],
#         'language': {'@classid': 'eng',
#          '@classname': 'English',
#          '@schemeid': 'dnet:languages',
#          '@schemename': 'dnet:languages'},
#         'relevantdate': [{'@classid': 'issued',
#           '@classname': 'issued',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '$': '2021-12-03'},
#          {'@classid': 'issued',
#           '@classname': 'issued',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '$': '2023-01-09'},
#          {'@classid': 'issued',
#           '@classname': 'issued',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '2021-04-28'},
#          {'@classid': 'issued',
#           '@classname': 'issued',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '2021-05-13'},
#          {'@classid': 'issued',
#           '@classname': 'issued',
#           '@schemeid': 'dnet:dataCite_date',
#           '@schemename': 'dnet:dataCite_date',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '2021-11-28'}],
#         'publisher': {'$': 'Zenodo'},
#         'resulttype': {'@classid': 'dataset',
#          '@classname': 'dataset',
#          '@schemeid': 'dnet:result_typologies',
#          '@schemename': 'dnet:result_typologies'},
#         'resourcetype': {'@classid': 'UNKNOWN',
#          '@classname': 'UNKNOWN',
#          '@schemeid': 'dnet:dataCite_resource',
#          '@schemename': 'dnet:dataCite_resource'},
#         'datainfo': {'inferred': {'$': True},
#          'deletedbyinference': {'$': False},
#          'trust': {'$': '0.8'},
#          'inferenceprovenance': {'$': 'dedup-result-decisiontree-v4'},
#          'provenanceaction': {'@classid': 'sysimport:dedup',
#           '@classname': 'Inferred by OpenAIRE',
#           '@schemeid': 'dnet:provenanceActions',
#           '@schemename': 'dnet:provenanceActions'}},
#         'rels': None,
#         'children': {'result': [{'@objidentifier': 'doi_________::ecc0ff1534438608931d88cb2c9cf8b2',
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'publisher': {'$': 'Zenodo'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7494341'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}},
#           {'@objidentifier': 'doi_________::ae34f1bc18ad7a467b581ff0f2a80011',
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'publisher': {'$': 'Zenodo'},
#            'dateofacceptance': {'$': '2021-12-03'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4728143'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}},
#           {'@objidentifier': 'doi_________::e4e4c9d9619ab9b415b90a28430bee9d',
#            'publisher': {'$': 'Zenodo'},
#            'dateofacceptance': {'$': '2021-12-03'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5751794'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}},
#           {'@objidentifier': 'doi_________::a54ee32a87f262047fc92f1cc6db47fc',
#            'publisher': {'$': 'Zenodo'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7494342'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}},
#           {'@objidentifier': 'doi_________::96dc0f5b18d34e3b2a2d27a9e27f37fa',
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7512738'},
#            'publisher': {'$': 'Zenodo'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}},
#           {'@objidentifier': 'doi_________::44fb8709b9e3424270b643a353190732',
#            'publisher': {'$': 'Zenodo'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5733317'},
#            'dateofacceptance': {'$': '2021-11-28'}},
#           {'@objidentifier': 'doi_________::6fecaa1c4009f0479182434dd7b349e4',
#            'dateofacceptance': {'$': '2021-04-28'},
#            'publisher': {'$': 'Zenodo'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4728144'}},
#           {'@objidentifier': 'doi_________::3ea65b4ce8275ebf616a709c25dc933a',
#            'publisher': {'$': 'Zenodo'},
#            'dateofacceptance': {'$': '2021-05-13'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4756748'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}},
#           {'@objidentifier': 'doi_________::06d6efd27ece7e6f70d9229a39931275',
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '$': 'CCG Starter Data Kit: Algeria'},
#            'publisher': {'$': 'Zenodo'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7512737'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}}],
#          'instance': [{'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-12-03'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5751794'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.5751794'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-05-13'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4756748'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4756748'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-11-28'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5733317'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.5733317'}}},
#           {'accessright': {'@classid': 'CLOSED',
#             '@classname': 'Closed Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7512738'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.7512738'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7494342'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.7494342'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7494341'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.7494341'}}},
#           {'accessright': {'@classid': 'CLOSED',
#             '@classname': 'Closed Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-09'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7512737'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.7512737'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-12-03'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4728143'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4728143'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-04-28'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4728144'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4728144'}}}]}}}}},
#     {'header': {'dri:objIdentifier': {'$': 'doi_dedup___::30b3493d0e3745753008fa7c93298879'},
#       'dri:dateOfCollection': {'$': '2023-01-15T16:13:25+0000'},
#       'dri:dateOfTransformation': {'$': '2023-01-15T16:13:25+0000'}},
#      'metadata': {'oaf:entity': {'@xsi:schemaLocation': 'http://namespace.openaire.eu/oaf https://www.openaire.eu/schema/1.0/oaf-1.0.xsd',
#        'oaf:result': {'collectedfrom': [{'@name': 'Datacite',
#           '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#          {'@name': 'ZENODO',
#           '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}],
#         'originalId': [{'$': '50|datacite____::30b3493d0e3745753008fa7c93298879'},
#          {'$': '10.5281/zenodo.4652804'},
#          {'$': '50|od______2659::f4219d3f26d587db3c18112f78c27ce7'},
#          {'$': 'oai:zenodo.org:4652805'},
#          {'$': 'oai:zenodo.org:7526341'},
#          {'$': '50|od______2659::5e79bd6dc9924c9b4856cdd17f8960dc'},
#          {'$': '50|od______2659::09e3ff18d055c9aa47835333c0fc060f'},
#          {'$': 'oai:zenodo.org:4756726'},
#          {'$': 'oai:zenodo.org:6478230'},
#          {'$': '50|od______2659::8e29b5d27f2e10135e90d5674b15c4ab'},
#          {'$': 'oai:zenodo.org:6478217'},
#          {'$': '50|od______2659::a9951bb17e8716ada4054b4bd7cf4e26'}],
#         'pid': [{'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:actionset',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4652804'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4652805'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.7526341'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.4756726'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.6478230'},
#          {'@classid': 'doi',
#           '@classname': 'Digital Object Identifier',
#           '@schemeid': 'dnet:pid_types',
#           '@schemename': 'dnet:pid_types',
#           '@inferred': False,
#           '@provenanceaction': 'sysimport:crosswalk:repository',
#           '@trust': '0.9',
#           '$': '10.5281/zenodo.6478217'}],
#         'measure': [{'@id': 'downloads', '@count': '355'},
#          {'@id': 'views', '@count': '257'},
#          {'@id': 'influence', '@score': '3.317285E-9', '@class': 'C5'},
#          {'@id': 'popularity', '@score': '4.174291E-9', '@class': 'C5'},
#          {'@id': 'influence_alt', '@score': '0', '@class': 'C5'},
#          {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'},
#          {'@id': 'impulse', '@score': '0', '@class': 'C5'}],
#         'title': {'@classid': 'main title',
#          '@classname': 'main title',
#          '@schemeid': 'dnet:dataCite_title',
#          '@schemename': 'dnet:dataCite_title',
#          '$': 'CCG Starter Data Kit: Egypt'},
#         'bestaccessright': {'@classid': 'OPEN',
#          '@classname': 'Open Access',
#          '@schemeid': 'dnet:access_modes',
#          '@schemename': 'dnet:access_modes'},
#         'creator': [{'@rank': '1',
#           '@name': 'Lucy',
# ...
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Ethiopia'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5710872'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-11-28'}},
#           {'@objidentifier': 'doi_________::9db4393c5458c18b2fbffb96e6c9f52c',
#            'publisher': {'$': 'Zenodo'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4650876'},
#            'dateofacceptance': {'$': '2023-01-16'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '$': 'CCG Starter Data Kit: Ethiopia'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}},
#           {'@objidentifier': 'doi_dedup___::96c7356234085515b5c2ea4b7bd06233',
#            'pid': [{'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.6478220'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.4756723'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.5710872'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:actionset',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.4650876'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.4993572'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.4650877'},
#             {'@classid': 'doi',
#              '@classname': 'Digital Object Identifier',
#              '@schemeid': 'dnet:pid_types',
#              '@schemename': 'dnet:pid_types',
#              '@inferred': False,
#              '@provenanceaction': 'sysimport:crosswalk:repository',
#              '@trust': '0.9',
#              '$': '10.5281/zenodo.7538968'}],
#            'collectedfrom': [{'@name': 'Datacite',
#              '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#             {'@name': 'ZENODO',
#              '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}],
#            'publisher': {'$': 'Zenodo'},
#            'dateofacceptance': {'$': '2023-01-16'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '$': 'CCG Starter Data Kit: Ethiopia'}},
#           {'@objidentifier': 'doi_________::08b5e54d0ac8740ba8b1cdd910cf06a8',
#            'publisher': {'$': 'Zenodo'},
#            'dateofacceptance': {'$': '2021-05-13'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Ethiopia'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4756723'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}},
#           {'@objidentifier': 'doi_________::96c7356234085515b5c2ea4b7bd06233',
#            'publisher': {'$': 'Zenodo'},
#            'title': {'@classid': 'main title',
#             '@classname': 'main title',
#             '@schemeid': 'dnet:dataCite_title',
#             '@schemename': 'dnet:dataCite_title',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': 'CCG Starter Data Kit: Ethiopia'},
#            'dateofacceptance': {'$': '2021-03-31'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4650877'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}}],
#          'instance': [{'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2022-04-22'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.6478220'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.6478220'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-11-28'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.5710872'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.5710872'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-05-13'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4756723'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4756723'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-16'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.7538968'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC BY'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.7538968'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-03-31'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4650877'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4650877'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2021-06-19'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:crosswalk:repository',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4993572'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC 0'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4993572'}}},
#           {'accessright': {'@classid': 'OPEN',
#             '@classname': 'Open Access',
#             '@schemeid': 'dnet:access_modes',
#             '@schemename': 'dnet:access_modes'},
#            'collectedfrom': {'@name': 'Datacite',
#             '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'},
#            'hostedby': {'@name': 'ZENODO',
#             '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'},
#            'dateofacceptance': {'$': '2023-01-16'},
#            'instancetype': {'@classid': '0021',
#             '@classname': 'Dataset',
#             '@schemeid': 'dnet:publication_resource',
#             '@schemename': 'dnet:publication_resource'},
#            'pid': {'@classid': 'doi',
#             '@classname': 'Digital Object Identifier',
#             '@schemeid': 'dnet:pid_types',
#             '@schemename': 'dnet:pid_types',
#             '@inferred': False,
#             '@provenanceaction': 'sysimport:actionset',
#             '@trust': '0.9',
#             '$': '10.5281/zenodo.4650876'},
#            'refereed': {'@classid': '0002',
#             '@classname': 'nonPeerReviewed',
#             '@schemeid': 'dnet:review_levels',
#             '@schemename': 'dnet:review_levels'},
#            'license': {'$': 'CC BY'},
#            'webresource': {'url': {'$': 'https://doi.org/10.5281/zenodo.4650876'}}}]}}}}}]},
#   'browseResults': None}}

# %%
for x in response.json()['response']['results']['result']:
    print(x['metadata']['oaf:entity']['oaf:result'])
# Out:
# {'collectedfrom': [{'@name': 'Crossref', '@id': 'openaire____::081b82f96300b6a6e3d282bad31cb6e2'}, {'@name': 'UnpayWall', '@id': 'openaire____::8ac8380272269217cb09a928c8caa993'}], 'originalId': [{'$': '10.21203/rs.3.rs-1160025/v1'}, {'$': '50|doiboost____::642e67d314304eb5dd5c5eb991372b4b'}], 'pid': {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '$': '10.21203/rs.3.rs-1160025/v1'}, 'measure': [{'@id': 'influence', '@score': '3.317285E-9', '@class': 'C5'}, {'@id': 'popularity', '@score': '3.0997787E-9', '@class': 'C5'}, {'@id': 'influence_alt', '@score': '0', '@class': 'C5'}, {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'}, {'@id': 'impulse', '@score': '0', '@class': 'C5'}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'Future low-carbon electricity in Africa: how much material is needed?'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Karla Cervantes', '@surname': 'Barron', '@orcid': '0000-0001-9185-3022', '$': 'Karla Cervantes Barron'}, {'@rank': '2', '@name': 'Maaike E', '@surname': 'Hakker', '$': 'Maaike E Hakker'}, {'@rank': '3', '@name': 'Jonathan M', '@surname': 'Cullen', '@orcid': '0000-0003-4347-5025', '$': 'Jonathan M Cullen'}], 'dateofacceptance': {'$': '2021-12-10'}, 'description': {'$': '<jats:title>Abstract</jats:title>         <jats:p>African countries are expected to experience some of the worst climate effects, while trying to provide higher electricity access and increase wellbeing.Concrete, steel, and aluminium pre\xadsent the largest opportunities for action, given their high mass or embodied emissions projections.Embodied emissions related to material use for electricity plants are evaluated in three scenarios: a refer\xadence scenario, and two scenarios related to the Paris Agreement (where renewable energy increases), resulting in higher embodied emissions as renewables are integrated.Pursuing strategies to increase the use of renewables should be done along material efficiency strategies to reach the total low-carbon potential.</jats:p>'}, 'language': {'@classid': 'und', '@classname': 'Undetermined', '@schemeid': 'dnet:languages', '@schemename': 'dnet:languages'}, 'relevantdate': [{'@classid': 'created', '@classname': 'created', '@schemeid': 'dnet:dataCite_date', '@schemename': 'dnet:dataCite_date', '$': '2021-12-10'}, {'@classid': 'available', '@classname': 'available', '@schemeid': 'dnet:dataCite_date', '@schemename': 'dnet:dataCite_date', '$': '2021-12-10'}, {'@classid': 'accepted', '@classname': 'accepted', '@schemeid': 'dnet:dataCite_date', '@schemename': 'dnet:dataCite_date', '$': '2021-12-10'}], 'publisher': {'$': 'Research Square Platform LLC'}, 'source': {'$': 'Crossref'}, 'resulttype': {'@classid': 'publication', '@classname': 'publication', '@schemeid': 'dnet:result_typologies', '@schemename': 'dnet:result_typologies'}, 'resourcetype': {'@classid': '0016', '@classname': 'Preprint', '@schemeid': 'dnet:publication_resource', '@schemename': 'dnet:publication_resource'}, 'isgreen': {'$': False}, 'openaccesscolor': {'$': 'hybrid'}, 'isindiamondjournal': {'$': False}, 'publiclyfunded': {'$': False}, 'datainfo': {'inferred': {'$': False}, 'deletedbyinference': {'$': False}, 'trust': {'$': '0.9'}, 'inferenceprovenance': {'$': 'null'}, 'provenanceaction': {'@classid': 'sysimport:actionset', '@classname': 'Harvested', '@schemeid': 'dnet:provenanceActions', '@schemename': 'dnet:provenanceActions'}}, 'rels': {'rel': {'@inferred': True, '@trust': '1.0', '@inferenceprovenance': 'bip:affiliation:crossref', '@provenanceaction': 'result:organization:bipinference', 'to': {'@class': 'hasAuthorInstitution', '@scheme': 'dnet:result_organization_relations', '@type': 'organization', '$': 'openorgs___ ...
# {'collectedfrom': [{'@name': 'Datacite', '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}, {'@name': 'ZENODO', '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'
@id': 'influence', '@score': '3.317285E-9', '@class': 'C5'}, {'@id': 'popularity', '@score': '4.174291E-9', '@class': 'C5'}, {'@id': 'influence_alt', '@score': '0', '@class': 'C5'}, {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'}, {'@id': 'impulse', '@score': '0', '@class': 'C5'}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'CCG Starter Data Kit: Congodemrep'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Carla', '@surname': 'Cannone', '@orcid_pending': '0000-0002-1214-8913', '$': 'Cannone, Carla'}, {'@rank': '2', '@name': 'Lucy', '@surname': 'Allington', '@orcid_pending': '0000-0003-1801-899x', '$': 'Allington, Lucy'}, {'@rank': '3', '@name': 'Ioannis', '@surname': 'Pappis', '@orcid_pending': '0000-0001-7537-5470', '$': 'Pappis, Ioannis'}, {'@rank': '4', '@name': 'Karla', '@surname': 'Cervantes Barron', '@orcid_pending': '0000-0001-9185-3022', '$': 'Cervantes Barron, Karla'}, {'@rank': '5', '@name': 'Will', '@surname': 'Usher', '@orcid_pending': '0000-0001-9367-1791', '$': 'Usher, Will'}, {'@rank': '6', '@name': 'Steve', '@surname': 'Pye', '@orcid_pending': '0000-0003-1793-2552', '$': 'Pye, Steve'}, {'@rank': '7', '@name': 'Edward', '@surname': 'Brown', '@orcid_pending': '0000-0002-0722-9348', '$': 'Brown, Edward'}, {'@rank': '8', '@name': 'Mark', '@surname': 'Howells', '@orcid_pending': '0000-0001-6419-4957', '$': 'Howells, Mark'}, {'@rank': '9', '@name': 'Miriam', '@surname': 'Zachau Walker', '@orcid_pending': '0000-0002-4757-3688', '$': 'Zachau Walker, Miriam'}, {'@rank': '10', '@name': 'Aniq', '@surname': 'Ahsan', '@orcid_pending': '0000-0002-6027-4818', '$': 'Ahsan, Aniq'}, {'@rank': '11', '@name': 'Flora', '@surname': 'Charbonnier', '@orcid_pending': '0000-0003-3174-0362', '$': 'Charbonnier, Flora'}, {'@rank': '12', '@name': 'Claire', '@surname': 'Halloran', '@orcid_pending': '0000-0002-0308-5623', '$': 'Halloran, Claire'}, {'@rank': '13', '@name': 'Stephanie', '@surname': 'Hirmer', '@orcid_pending': '0000-0001-7628-9259', '$': 'Hirmer, Stephanie'}, {'@rank': '14', '@name': 'Constantinos', '@surname': 'Taliotis', '@orcid': '0000-0003-4022-5506', '$': 'Taliotis, Constantinos'}, {'@rank': '15', '@name': 'Caroline', '@surname': 'Sundin', '$': 'Sundin, Caroline'}, {'@rank': '16', '@name': 'Vignesh', '@surname': 'Sridharan', '@orcid_pending': '0000-0003-0764-2615', '$': 'Sridharan, Vignesh'}, {'@rank': '17', '@name': 'Eunice', '@surname': 'Ramos', '@orcid_pending': '0000-0001-9061-8485', '$': 'Ramos, Eunice'}, {'@rank': '18', '@name': 'Maarten', '@surname': 'Brinkerink', '@orcid_pending': '0000-0002-8980-9062', '$': 'Brinkerink, Maarten'}, {'@rank': '19', '@name': 'Paul', '@surname': 'Deane', '@orcid_pending': '0000-0002-4681-7791', '$': 'Deane, Paul'}, {'@rank': '20', '@name': 'Andrii', '@surname': 'Gritsevskyi', '$': 'Gritsevskyi, Andri ...
# {'collectedfrom': [{'@name': 'Datacite', '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}, {'@name': 'ZENODO', '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'
}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'CCG Starter Data Kit: Angola'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Lucy', '@surname': 'Allington', '@orcid_pending': '0000-0003-1801-899x', '$': 'Allington, Lucy'}, {'@rank': '2', '@name': 'Carla', '@surname': 'Cannone', '@orcid_pending': '0000-0002-1214-8913', '$': 'Cannone, Carla'}, {'@rank': '3', '@name': 'Ioannis', '@surname': 'Pappis', '@orcid_pending': '0000-0001-7537-5470', '$': 'Pappis, Ioannis'}, {'@rank': '4', '@name': 'Karla', '@surname': 'Cervantes Barron', '@orcid_pending': '0000-0001-9185-3022', '$': 'Cervantes Barron, Karla'}, {'@rank': '5', '@name': 'Will', '@surname': 'Usher', '@orcid_pending': '0000-0001-9367-1791', '$': 'Usher, Will'}, {'@rank': '6', '@name': 'Steve', '@surname': 'Pye', '@orcid_pending': '0000-0003-1793-2552', '$': 'Pye, Steve'}, {'@rank': '7', '@name': 'Mark', '@surname': 'Howells', '@orcid_pending': '0000-0001-6419-4957', '$': 'Howells, Mark'}, {'@rank': '8', '@name': 'Constantinos', '@surname': 'Taliotis', '@orcid': '0000-0003-4022-5506', '$': 'Taliotis, Constantinos'}, {'@rank': '9', '@name': 'Caroline', '@surname': 'Sundin', '$':  ...
# {'collectedfrom': [{'@name': 'Datacite', '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}, {'@name': 'ZENODO', '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}], 'originalId': [{'$': '50|datacite____::a56e46d41272092ad1205a1a57947490'}, {'$': '10.5281/zenodo.4650822'}, {'$': '50|od______2659::ea644bfeb8251bbd7beb5f7286b247f0'}, {'$': 'oai:zenodo.org:4756738'}, {'$': 'oai:zenodo.org:7526331'}, {'$': '50|od______2659::c427e37d8a08df2c38bc8b6d9fd33505'}, {'$': '50|od______2659::eb770d28511c57f2d98738d8083d1be1'}, {'$': 'oai:zenodo.org:4650823'}], 'pid': [{'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:actionset', '@trust': '0.9', '$': '10.5281/zenodo.4650822'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.4756738'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.7526331'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.4650823'}], 'measure': [{'@id': 'influence', '@score': '3.317285E-9', '@class': 'C5'}, {'@id': 'popularity', '@score': '4.174291E-9', '@class': 'C5'}, {'@id': 'influence_alt', '@score': '0', '@class': 'C5'}, {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'}, {'@id': 'impulse', '@score': '0', '@class': 'C5'}, {'@id': 'downloads', '@count': '147'}, {'@id': 'views', '@count': '103'}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'CCG Starter Data Kit: Cameroon'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Lucy', '@surname': 'Allington', '@orcid_pending': '0000-0003-1801-899x', '$': 'Allington, Lucy'}, {'@rank': '2', '@name': 'Carla', '@surname': 'Cannone', '@orcid_pending': '0000-0002-1214-8913', '$': 'Cannone, Carla'}, {'@rank': '3', '@name': 'Ioannis', '@surname': 'Pappis', '@orcid_pending': '0000-0001-7537-5470', '$': 'Pappis, Ioannis'}, {'@rank': '4', '@name': 'Miriam', '@surname': 'Zachau Walker', '@orcid_pending': '0000-0002-4757-3688', '$': 'Zachau Walker, Miriam'}, {'@rank': '5', '@name': 'Claire', '@surname': 'Halloran', '@orcid_pending': '0000-0002-0308-5623', '$': 'Halloran, Claire'}, {'@rank': '6', '@name': 'Stephanie', '@surname': 'Hirmer', '@orcid_pending': '0000-0001-7628-9259', '$': 'Hirmer, Stephanie'}, {'@rank': '7', '@name': 'Karla', '@surname': 'Cervantes Barron', '@orcid_pending': '0000-0001-9185-3022', '$': 'Cervantes Barron, Karla'}, {'@rank': '8', '@name': 'Will', '@surname': 'Usher', '@orcid_pending': '0000-0001-9367-1791', '$': 'Usher, Will'}, {'@rank': '9', '@name': 'Steve', '@surname': 'Pye', '@orcid_pending': '0000-0003-1793-2552', '$': 'Pye, Steve'}, {'@rank': '10', '@name': 'Mark', '@surname': 'Howells', '@orcid_pending': '0000-0001-6419-4957', '$': 'Howells, Mark'}, {'@rank': '11', '@name': 'Constantinos', '@surname': 'Taliotis', '@orcid': '0000-0003-4022-5506', '$': 'Taliotis, Constantinos'}, {'@rank': '12', '@name': 'Caroline', '@surname': 'Sundin', '$': 'Sundin, Caroline'}, {'@rank': '13', '@name': 'Vignesh', '@surname': 'Sridharan', '@orcid_pending': '0000-0003-0764-2615', '$': 'Sridharan, Vignesh'}, {'@rank': '14', '@name': 'Eunice', '@surname': 'Ramos', '@orcid_pending': '0000-0001-9061-8485', '$': 'Ramos, Eunice'}, {'@rank': '15' ...
# {'collectedfrom': [{'@name': 'Crossref', '@id': 'openaire____::081b82f96300b6a6e3d282bad31cb6e2'}, {'@name': 'UnpayWall', '@id': 'openaire____::8ac8380272269217cb09a928c8caa993'}, {'@name': 'DOAJ-Articles', '@id': 'driver______::bee53aa31dc2cbb538c10c2b65fa5824'}], 'originalId': [{'$': 'S2211467X21001826'}, {'$': '10.1016/j.esr.2021.100799'}, {'$': '50|doiboost____::289c132123e70f572fa62d71a1769bea'}, {'$': '50|doajarticles::b50ecc1b8ce185185463f85edfa24f72'}, {'$': 'oai:doaj.org/article:e620d639098d4632bf5e5fb5dee8d815'}], 'pid': {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '$': '10.1016/j.esr.2021.100799'}, 'measure': [{'@id': 'influence', '@score': '3.521678E-9', '@class': 'C5'}, {'@id': 'popularity', '@score': '8.943896E-9', '@class': 'C4'}, {'@id': 'influence_alt', '@score': '4', '@class': 'C5'}, {'@id': 'popularity_alt', '@score': '2.8', '@class': 'C4'}, {'@id': 'impulse', '@score': '4', '@class': 'C5'}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'Bank climate actions and their implications for the coal power sector'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Hoy-Yen', '@surname': 'Chan', '@orcid_pending': '0000-0003-1263-1654', '$': 'Hoy-Yen Chan'}, {'@rank': '2', '@name': 'Monika', '@surname': 'Merdekawati', '$': 'Monika Merdekawati'}, {'@rank': '3', '@name': 'Beni', '@surname': 'Suryadi', '$': 'Beni Suryadi'}], 'dateofacceptance': {'$': '2022-01-01'}, 'description': {'$': "Financial institutions around the world have announced halts to financing of coal-fired power plants (CFPPs). Non-profit and non-governmental organisations have financing, developed databases and reports that provide information on financial data and CFPP projects, as well as the quality of the coal policies of financial institutions. In this study, we integrated information from these databases and analysed the financing implications for CFPP development. We selected the world's 56 largest commercial banks and reviewed and mapped their coal policies according to four common financing conditions. We also analysed bank contributions via project and corporate finance, selecting Indonesia as a country-specific case study to examine how and to what extent banks have been supporting the coal industry. Our analysis revealed that banks have been financing the CFPP industry more substantially through corporate finance than project finance. Consequently, we suggest that the most effective financing policies consist of a combination of exclusion criteria that transparently address project and corporate financing and enhance bank positions by setting a coal phase-out target. Besides, more banks are offering sustainable finance, in which the budget committed to sustainability is larger than the amount historically financed for fossil fuels. Our findings conclude that commercial banks can potentially influence development of the coal power sector, even in a country like Indonesia where it is highly supported by public finance."}, 'subject': [{'@classid': 'keyword', '@classname': 'keyword', '@schemeid': 'dnet:subject_classification_typologies', '@schemename': 'dnet:subject_classification_typologies', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': 'Coal financing'}, {'@classid': 'keyword', '@classname': 'keyword', '@schemeid': 'dnet:subject_classification_typologies', '@schemename': 'dnet:subject_classification_typologies', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': 'Corporate finance'}, {'@classid': 'keyword', '@classname': 'keyword', '@schemeid': 'dnet:subject_classification_typologies', '@schemename': 'dnet:subject_classification_typologies', '@i ...
# {'collectedfrom': [{'@name': 'Datacite', '@id': 'openaire____::9e3be59865b2c1c335d32dae2fe7b254'}, {'@name': 'ZENODO', '@id': 'opendoar____::358aee4cc897452c00244351e4d91f69'}], 'originalId': [{'$': '50|datacite____::9db4393c5458c18b2fbffb96e6c9f52c'}, {'$': '10.5281/zenodo.4650876'}, {'$': '50|od______2659::8343641c53086509b1707c1c02279300'}, {'$': 'oai:zenodo.org:6478220'}, {'$': 'oai:zenodo.org:4650877'}, {'$': '50|od______2659::c7815eb4bb4df66d34abfac29fdfd3b3'}, {'$': 'oai:zenodo.org:5710872'}, {'$': '50|od______2659::3573ebf101f62b2efbe9545a069f2db7'}, {'$': '50|od______2659::abc970476523e9a25a361d701f9a140d'}, {'$': 'oai:zenodo.org:7538968'}, {'$': '50|od______2659::97fc935874641fa9fd0f01c2e322d39f'}, {'$': 'oai:zenodo.org:4756723'}, {'$': 'oai:zenodo.org:4993572'}, {'$': '50|od______2659::6fad95cc83f7ffab71ff961be25f4fa4'}], 'pid': [{'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:actionset', '@trust': '0.9', '$': '10.5281/zenodo.4650876'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.6478220'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.4650877'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.5710872'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.7538968'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.4756723'}, {'@classid': 'doi', '@classname': 'Digital Object Identifier', '@schemeid': 'dnet:pid_types', '@schemename': 'dnet:pid_types', '@inferred': False, '@provenanceaction': 'sysimport:crosswalk:repository', '@trust': '0.9', '$': '10.5281/zenodo.4993572'}], 'measure': [{'@id': 'influence', '@score': '3.317285E-9', '@class': 'C5'}, {'@id': 'popularity', '@score': '4.174291E-9', '@class': 'C5'}, {'@id': 'influence_alt', '@score': '0', '@class': 'C5'}, {'@id': 'popularity_alt', '@score': '0.0', '@class': 'C5'}, {'@id': 'impulse', '@score': '0', '@class': 'C5'}, {'@id': 'downloads', '@count': '690'}, {'@id': 'views', '@count': '412'}], 'title': {'@classid': 'main title', '@classname': 'main title', '@schemeid': 'dnet:dataCite_title', '@schemename': 'dnet:dataCite_title', '$': 'CCG Starter Data Kit: Ethiopia'}, 'bestaccessright': {'@classid': 'OPEN', '@classname': 'Open Access', '@schemeid': 'dnet:access_modes', '@schemename': 'dnet:access_modes'}, 'creator': [{'@rank': '1', '@name': 'Carla', '@surname': 'Cannone', '@orcid_pending': '0000-0002-1214-8913', '$': 'Cannone, Carla'}, {'@rank': '2', '@name': 'Lucy', '@surname': 'Allington', '@orcid_pending': '0000-0003-1801-899x', '$': 'Allington, Lucy'}, {'@rank': '3', '@name': 'Ioannis', '@surname': 'Pappis', '@orcid_pending': '0000-0001-7537-5470', '$': 'Pappis, Ioannis'}, {'@rank': '4', '@name': 'Karla', '@surname': 'Cervantes Barron', '@orcid_pending': '0000-0001-9185-3022', '$': 'Cervantes Barron, Karla'}, {'@rank': '5', '@name': 'Will', '@surname': 'Usher', '@orcid_pending': '0000-0001-9367-1791', '$': 'Usher, Will'}, {'@rank': '6', '@name': 'Steve', '@surname': 'Pye', '@orcid_pending ...

# %%
import re
from html import unescape

CLEANR = re.compile('<.*?>')

def clean_html(raw_html):
    """Remove HTML markup from a string
    """
    cleantext = re.sub(CLEANR, '', raw_html)
    return unescape(cleantext)

for result in response.json()['response']['results']['result']:

    entity = result['metadata']['oaf:entity']['oaf:result']

    title = entity['title']
    if isinstance(title, list):
        count = 0
        for x in title:
            count += 1
            print(f"{count}: {x}")
            if x['@classid'] == 'main title':
                print(x['$'])
            else:
                pass
    else:
        print(title['$'])

    # print(entity.keys())

    authors = entity['creator']

    publisher = entity['publisher']

    journal = entity.get('journal', {'$': ''})

    abstract = entity.get('description', {'$': ''})

    try:
        all_authors = []
        for x in authors:
            name = x.get("$", "No name")
            orcid = x.get('@orcid', "No ORCID")
            all_authors.append(f"{name} ({orcid})")
        print(", ".join(all_authors))
    except TypeError as ex:
        print(authors['$'])

    print(publisher['$'])
    print(journal['$'])
    print(clean_html(abstract['$']))
# Out:
# Future low-carbon electricity in Africa: how much material is needed?
# Karla Cervantes Barron (0000-0001-9185-3022), Maaike E Hakker (No ORCID), Jonathan M Cullen (0000-0003-4347-5025)
# Research Square Platform LLC
#
# Abstract         African countries are expected to experience some of the worst climate effects, while trying to provide higher electricity access and increase wellbeing.Concrete, steel, and aluminium pre­sent the largest opportunities for action, given their high mass or embodied emissions projections.Embodied emissions related to material use for electricity plants are evaluated in three scenarios: a refer­ence scenario, and two scenarios related to the Paris Agreement (where renewable energy increases), resulting in higher embodied emissions as renewables are integrated.Pursuing strategies to increase the use of renewables should be done along material efficiency strategies to reach the total low-carbon potential.
# CCG Starter Data Kit: Algeria
# Cannone, Carla (No ORCID), Allington, Lucy (No ORCID), Pappis, Ioannis (No ORCID), Cervantes Barron, Karla (No ORCID), Usher, Will (No ORCID), Pye, Steve (No ORCID), Howells, Mark (No ORCID), Zachau Walker, Miriam (No ORCID), Ahsan, Aniq (No ORCID), Charbonnier, Flora (No ORCID), Halloran, Claire (No ORCID), Hirmer, Stephanie (No ORCID), Taliotis, Constantinos (0000-0003-4022-5506), Sundin, Caroline (No ORCID), Sridharan, Vignesh (No ORCID), Ramos, Eunice (No ORCID), Brinkerink, Maarten (No ORCID), Deane, Paul (No ORCID), Gritsevskyi, Andrii (No ORCID), Moura, Gustavo (No ORCID), Rouget, Arnaud (No ORCID), Wogan, David (No ORCID), Barcelona, Edito (No ORCID), Rogner, Holger (No ORCID)
# Zenodo
#
# A starter data kit for Algeria
# CCG Starter Data Kit: Egypt
# Allington, Lucy (No ORCID), Cannone, Carla (No ORCID), Pappis, Ioannis (No ORCID), Cervantes Barron, Karla (No ORCID), Usher, Will (No ORCID), Pye, Steve (No ORCID), Howells, Mark (0000-0001-6419-4957), Taliotis, Constantinos (0000-0003-4022-5506), Sundin, Caroline (No ORCID), Sridharan, Vignesh (No ORCID), Ramos, Eunice (No ORCID), Brinkerink, Maarten (No ORCID), Deane, Paul (No ORCID), Gritsevskyi, Andrii (No ORCID), Moura, Gustavo (No ORCID), Rouget, Arnaud (No ORCID), Wogan, David (No ORCID), Barcelona, Edito (No ORCID), Rogner, Holger (No ORCID)
